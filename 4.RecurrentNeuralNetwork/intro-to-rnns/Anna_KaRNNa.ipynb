# %% [markdown]
# # Anna KaRNNa
#
# In this notebook, I'll build a character-wise RNN trained on Anna Karenina, one of my all-time favorite books. It'll be able to generate new text based on the text from the book.
#
# This network is based off of Andrej Karpathy's [post on RNNs](http://karpathy.github.io/2015/05/21/rnn-effectiveness/) and [implementation in Torch](https://github.com/karpathy/char-rnn). Also, some information [here at r2rt](http://r2rt.com/recurrent-neural-networks-in-tensorflow-ii.html) and from [Sherjil Ozair](https://github.com/sherjilozair/char-rnn-tensorflow) on GitHub. Below is the general architecture of the character-wise RNN.
#
# <img src="assets/charseq.jpeg" width="500">

# %%
import time
from collections import namedtuple

import numpy as np
import tensorflow as tf

# %% [markdown]
# First we'll load the text file and convert it into integers for our network to use. Here I'm creating a couple dictionaries to convert the characters to and from integers. Encoding the characters as integers makes it easier to use as input in the network.

# %%
with open('anna.txt', 'r') as f:
    text=f.read()
vocab = sorted(set(text))
vocab_to_int = {c: i for i, c in enumerate(vocab)}
int_to_vocab = dict(enumerate(vocab))
encoded = np.array([vocab_to_int[c] for c in text], dtype=np.int32)

# %% [markdown]
# Let's check out the first 100 characters, make sure everything is peachy. According to the [American Book Review](http://americanbookreview.org/100bestlines.asp), this is the 6th best first line of a book ever.

# %%
text[:100]
# Out:
# 'Chapter 1\n\n\nHappy families are all alike; every unhappy family is unhappy in its own\nway.\n\nEverythin'

# %% [markdown]
# And we can see the characters encoded as integers.

# %%
encoded[:100]
# Out:
# array([31, 64, 57, 72, 76, 61, 74,  1, 16,  0,  0,  0, 36, 57, 72, 72, 81,
#         1, 62, 57, 69, 65, 68, 65, 61, 75,  1, 57, 74, 61,  1, 57, 68, 68,
#         1, 57, 68, 65, 67, 61, 26,  1, 61, 78, 61, 74, 81,  1, 77, 70, 64,
#        57, 72, 72, 81,  1, 62, 57, 69, 65, 68, 81,  1, 65, 75,  1, 77, 70,
#        64, 57, 72, 72, 81,  1, 65, 70,  1, 65, 76, 75,  1, 71, 79, 70,  0,
#        79, 57, 81, 13,  0,  0, 33, 78, 61, 74, 81, 76, 64, 65, 70], dtype=int32)

# %% [markdown]
# Since the network is working with individual characters, it's similar to a classification problem in which we are trying to predict the next character from the previous text.  Here's how many 'classes' our network has to pick from.

# %%
len(vocab)
# Out:
# 83

# %% [markdown]
# ## Making training mini-batches
#
# Here is where we'll make our mini-batches for training. Remember that we want our batches to be multiple sequences of some desired number of sequence steps. Considering a simple example, our batches would look like this:
#
# <img src="assets/sequence_batching@1x.png" width=500px>
#
#
# <br>
# We have our text encoded as integers as one long array in `encoded`. Let's create a function that will give us an iterator for our batches. I like using [generator functions](https://jeffknupp.com/blog/2013/04/07/improve-your-python-yield-and-generators-explained/) to do this. Then we can pass `encoded` into this function and get our batch generator.
#
# The first thing we need to do is discard some of the text so we only have completely full batches. Each batch contains $N \times M$ characters, where $N$ is the batch size (the number of sequences) and $M$ is the number of steps. Then, to get the number of batches we can make from some array `arr`, you divide the length of `arr` by the batch size. Once you know the number of batches and the batch size, you can get the total number of characters to keep.
#
# After that, we need to split `arr` into $N$ sequences. You can do this using `arr.reshape(size)` where `size` is a tuple containing the dimensions sizes of the reshaped array. We know we want $N$ sequences (`n_seqs` below), let's make that the size of the first dimension. For the second dimension, you can use `-1` as a placeholder in the size, it'll fill up the array with the appropriate data for you. After this, you should have an array that is $N \times (M * K)$ where $K$ is the number of batches.
#
# Now that we have this array, we can iterate through it to get our batches. The idea is each batch is a $N \times M$ window on the array. For each subsequent batch, the window moves over by `n_steps`. We also want to create both the input and target arrays. Remember that the targets are the inputs shifted over one character. You'll usually see the first input character used as the last target character, so something like this:
# ```python
# y[:, :-1], y[:, -1] = x[:, 1:], x[:, 0]
# ```
# where `x` is the input batch and `y` is the target batch.
#
# The way I like to do this window is use `range` to take steps of size `n_steps` from $0$ to `arr.shape[1]`, the total number of steps in each sequence. That way, the integers you get from `range` always point to the start of a batch, and each window is `n_steps` wide.

# %%
def get_batches(arr, n_seqs, n_steps):
    '''Create a generator that returns batches of size
       n_seqs x n_steps from arr.
       
       Arguments
       ---------
       arr: Array you want to make batches from
       n_seqs: Batch size, the number of sequences per batch
       n_steps: Number of sequence steps per batch
    '''
    # Get the number of characters per batch and number of batches we can make
    characters_per_batch = n_seqs * n_steps
    n_batches = len(arr)//characters_per_batch
    
    # Keep only enough characters to make full batches
    arr = arr[:n_batches * characters_per_batch]
    
    # Reshape into n_seqs rows
    arr = arr.reshape((n_seqs, -1))
    
    for n in range(0, arr.shape[1], n_steps):
        # The features
        x = arr[:, n:n+n_steps]
        # The targets, shifted by one
        y = np.zeros_like(x)
        y[:, :-1], y[:, -1] = x[:, 1:], x[:, 0]
        yield x, y

# %% [markdown]
# Now I'll make my data sets and we can check out what's going on here. Here I'm going to use a batch size of 10 and 50 sequence steps.

# %%
batches = get_batches(encoded, 10, 50)
x, y = next(batches)

# %%
print('x\n', x[:10, :10])
print('\ny\n', y[:10, :10])
# Out:
# x
#  [[31 64 57 72 76 61 74  1 16  0]
#  [ 1 57 69  1 70 71 76  1 63 71]
#  [78 65 70 13  0  0  3 53 61 75]
#  [70  1 60 77 74 65 70 63  1 64]
#  [ 1 65 76  1 65 75 11  1 75 65]
#  [ 1 37 76  1 79 57 75  0 71 70]
#  [64 61 70  1 59 71 69 61  1 62]
#  [26  1 58 77 76  1 70 71 79  1]
#  [76  1 65 75 70  7 76 13  1 48]
#  [ 1 75 57 65 60  1 76 71  1 64]]
#
# y
#  [[64 57 72 76 61 74  1 16  0  0]
#  [57 69  1 70 71 76  1 63 71 65]
#  [65 70 13  0  0  3 53 61 75 11]
#  [ 1 60 77 74 65 70 63  1 64 65]
#  [65 76  1 65 75 11  1 75 65 74]
#  [37 76  1 79 57 75  0 71 70 68]
#  [61 70  1 59 71 69 61  1 62 71]
#  [ 1 58 77 76  1 70 71 79  1 75]
#  [ 1 65 75 70  7 76 13  1 48 64]
#  [75 57 65 60  1 76 71  1 64 61]]

# %% [markdown]
# If you implemented `get_batches` correctly, the above output should look something like
# ```
# x
#  [[55 63 69 22  6 76 45  5 16 35]
#  [ 5 69  1  5 12 52  6  5 56 52]
#  [48 29 12 61 35 35  8 64 76 78]
#  [12  5 24 39 45 29 12 56  5 63]
#  [ 5 29  6  5 29 78 28  5 78 29]
#  [ 5 13  6  5 36 69 78 35 52 12]
#  [63 76 12  5 18 52  1 76  5 58]
#  [34  5 73 39  6  5 12 52 36  5]
#  [ 6  5 29 78 12 79  6 61  5 59]
#  [ 5 78 69 29 24  5  6 52  5 63]]
#
# y
#  [[63 69 22  6 76 45  5 16 35 35]
#  [69  1  5 12 52  6  5 56 52 29]
#  [29 12 61 35 35  8 64 76 78 28]
#  [ 5 24 39 45 29 12 56  5 63 29]
#  [29  6  5 29 78 28  5 78 29 45]
#  [13  6  5 36 69 78 35 52 12 43]
#  [76 12  5 18 52  1 76  5 58 52]
#  [ 5 73 39  6  5 12 52 36  5 78]
#  [ 5 29 78 12 79  6 61  5 59 63]
#  [78 69 29 24  5  6 52  5 63 76]]
#  ```
#  although the exact numbers will be different. Check to make sure the data is shifted over one step for `y`.

# %% [markdown]
# ## Building the model
#
# Below is where you'll build the network. We'll break it up into parts so it's easier to reason about each bit. Then we can connect them up into the whole network.
#
# <img src="assets/charRNN.png" width=500px>
#
#
# ### Inputs
#
# First off we'll create our input placeholders. As usual we need placeholders for the training data and the targets. We'll also create a placeholder for dropout layers called `keep_prob`.

# %%
def build_inputs(batch_size, num_steps):
    ''' Define placeholders for inputs, targets, and dropout 
    
        Arguments
        ---------
        batch_size: Batch size, number of sequences per batch
        num_steps: Number of sequence steps in a batch
        
    '''
    # Declare placeholders we'll feed into the graph
    inputs = tf.placeholder(tf.int32, [batch_size, num_steps], name='inputs')
    targets = tf.placeholder(tf.int32, [batch_size, num_steps], name='targets')
    
    # Keep probability placeholder for drop out layers
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    
    return inputs, targets, keep_prob

# %% [markdown]
# ### LSTM Cell
#
# Here we will create the LSTM cell we'll use in the hidden layer. We'll use this cell as a building block for the RNN. So we aren't actually defining the RNN here, just the type of cell we'll use in the hidden layer.
#
# We first create a basic LSTM cell with
#
# ```python
# lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
# ```
#
# where `num_units` is the number of units in the hidden layers in the cell. Then we can add dropout by wrapping it with
#
# ```python
# tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
# ```
# You pass in a cell and it will automatically add dropout to the inputs or outputs. Finally, we can stack up the LSTM cells into layers with [`tf.contrib.rnn.MultiRNNCell`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/rnn/MultiRNNCell). With this, you pass in a list of cells and it will send the output of one cell into the next cell. Previously with TensorFlow 1.0, you could do this
#
# ```python
# tf.contrib.rnn.MultiRNNCell([cell]*num_layers)
# ```
#
# This might look a little weird if you know Python well because this will create a list of the same `cell` object. However, TensorFlow 1.0 will create different weight matrices for all `cell` objects. But, starting with TensorFlow 1.1 you actually need to create new cell objects in the list. To get it to work in TensorFlow 1.1, it should look like
#
# ```python
# def build_cell(num_units, keep_prob):
#     lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
#     drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
#
#     return drop
#
# tf.contrib.rnn.MultiRNNCell([build_cell(num_units, keep_prob) for _ in range(num_layers)])
# ```
#
# Even though this is actually multiple LSTM cells stacked on each other, you can treat the multiple layers as one cell.
#
# We also need to create an initial cell state of all zeros. This can be done like so
#
# ```python
# initial_state = cell.zero_state(batch_size, tf.float32)
# ```
#
# Below, we implement the `build_lstm` function to create these LSTM cells and the initial state.

# %%
def build_lstm(lstm_size, num_layers, batch_size, keep_prob):
    ''' Build LSTM cell.
    
        Arguments
        ---------
        keep_prob: Scalar tensor (tf.placeholder) for the dropout keep probability
        lstm_size: Size of the hidden layers in the LSTM cells
        num_layers: Number of LSTM layers
        batch_size: Batch size

    '''
    ### Build the LSTM Cell
    
    def build_cell(lstm_size, keep_prob):
        # Use a basic LSTM cell
        lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)
        
        # Add dropout to the cell
        drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
        return drop
    
    
    # Stack up multiple LSTM layers, for deep learning
    cell = tf.contrib.rnn.MultiRNNCell([build_cell(lstm_size, keep_prob) for _ in range(num_layers)])
    initial_state = cell.zero_state(batch_size, tf.float32)
    
    return cell, initial_state

# %% [markdown]
# ### RNN Output
#
# Here we'll create the output layer. We need to connect the output of the RNN cells to a full connected layer with a softmax output. The softmax output gives us a probability distribution we can use to predict the next character.
#
# If our input has batch size $N$, number of steps $M$, and the hidden layer has $L$ hidden units, then the output is a 3D tensor with size $N \times M \times L$. The output of each LSTM cell has size $L$, we have $M$ of them, one for each sequence step, and we have $N$ sequences. So the total size is $N \times M \times L$.
#
# We are using the same fully connected layer, the same weights, for each of the outputs. Then, to make things easier, we should reshape the outputs into a 2D tensor with shape $(M * N) \times L$. That is, one row for each sequence and step, where the values of each row are the output from the LSTM cells.
#
# One we have the outputs reshaped, we can do the matrix multiplication with the weights. We need to wrap the weight and bias variables in a variable scope with `tf.variable_scope(scope_name)` because there are weights being created in the LSTM cells. TensorFlow will throw an error if the weights created here have the same names as the weights created in the LSTM cells, which they will be default. To avoid this, we wrap the variables in a variable scope so we can give them unique names.

# %%
def build_output(lstm_output, in_size, out_size):
    ''' Build a softmax layer, return the softmax output and logits.
    
        Arguments
        ---------
        
        x: Input tensor
        in_size: Size of the input tensor, for example, size of the LSTM cells
        out_size: Size of this softmax layer
    
    '''

    # Reshape output so it's a bunch of rows, one row for each step for each sequence.
    # That is, the shape should be batch_size*num_steps rows by lstm_size columns
    seq_output = tf.concat(lstm_output, axis=1)
    x = tf.reshape(seq_output, [-1, in_size])
    
    # Connect the RNN outputs to a softmax layer
    with tf.variable_scope('softmax'):
        softmax_w = tf.Variable(tf.truncated_normal((in_size, out_size), stddev=0.1))
        softmax_b = tf.Variable(tf.zeros(out_size))
    
    # Since output is a bunch of rows of RNN cell outputs, logits will be a bunch
    # of rows of logit outputs, one for each step and sequence
    logits = tf.matmul(x, softmax_w) + softmax_b
    
    # Use softmax to get the probabilities for predicted characters
    out = tf.nn.softmax(logits, name='predictions')
    
    return out, logits

# %% [markdown]
# ### Training loss
#
# Next up is the training loss. We get the logits and targets and calculate the softmax cross-entropy loss. First we need to one-hot encode the targets, we're getting them as encoded characters. Then, reshape the one-hot targets so it's a 2D tensor with size $(M*N) \times C$ where $C$ is the number of classes/characters we have. Remember that we reshaped the LSTM outputs and ran them through a fully connected layer with $C$ units. So our logits will also have size $(M*N) \times C$.
#
# Then we run the logits and targets through `tf.nn.softmax_cross_entropy_with_logits` and find the mean to get the loss.

# %%
def build_loss(logits, targets, lstm_size, num_classes):
    ''' Calculate the loss from the logits and the targets.
    
        Arguments
        ---------
        logits: Logits from final fully connected layer
        targets: Targets for supervised learning
        lstm_size: Number of LSTM hidden units
        num_classes: Number of classes in targets
        
    '''
    
    # One-hot encode targets and reshape to match logits, one row per batch_size per step
    y_one_hot = tf.one_hot(targets, num_classes)
    y_reshaped = tf.reshape(y_one_hot, logits.get_shape())
    
    # Softmax cross entropy loss
    loss = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y_reshaped)
    loss = tf.reduce_mean(loss)
    return loss

# %% [markdown]
# ### Optimizer
#
# Here we build the optimizer. Normal RNNs have have issues gradients exploding and disappearing. LSTMs fix the disappearance problem, but the gradients can still grow without bound. To fix this, we can clip the gradients above some threshold. That is, if a gradient is larger than that threshold, we set it to the threshold. This will ensure the gradients never grow overly large. Then we use an AdamOptimizer for the learning step.

# %%
def build_optimizer(loss, learning_rate, grad_clip):
    ''' Build optmizer for training, using gradient clipping.
    
        Arguments:
        loss: Network loss
        learning_rate: Learning rate for optimizer
    
    '''
    
    # Optimizer for training, using gradient clipping to control exploding gradients
    tvars = tf.trainable_variables()
    grads, _ = tf.clip_by_global_norm(tf.gradients(loss, tvars), grad_clip)
    train_op = tf.train.AdamOptimizer(learning_rate)
    optimizer = train_op.apply_gradients(zip(grads, tvars))
    
    return optimizer

# %% [markdown]
# ### Build the network
#
# Now we can put all the pieces together and build a class for the network. To actually run data through the LSTM cells, we will use [`tf.nn.dynamic_rnn`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/nn/dynamic_rnn). This function will pass the hidden and cell states across LSTM cells appropriately for us. It returns the outputs for each LSTM cell at each step for each sequence in the mini-batch. It also gives us the final LSTM state. We want to save this state as `final_state` so we can pass it to the first LSTM cell in the the next mini-batch run. For `tf.nn.dynamic_rnn`, we pass in the cell and initial state we get from `build_lstm`, as well as our input sequences. Also, we need to one-hot encode the inputs before going into the RNN.

# %%
class CharRNN:
    
    def __init__(self, num_classes, batch_size=64, num_steps=50, 
                       lstm_size=128, num_layers=2, learning_rate=0.001, 
                       grad_clip=5, sampling=False):
    
        # When we're using this network for sampling later, we'll be passing in
        # one character at a time, so providing an option for that
        if sampling == True:
            batch_size, num_steps = 1, 1
        else:
            batch_size, num_steps = batch_size, num_steps

        tf.reset_default_graph()
        
        # Build the input placeholder tensors
        self.inputs, self.targets, self.keep_prob = build_inputs(batch_size, num_steps)

        # Build the LSTM cell
        cell, self.initial_state = build_lstm(lstm_size, num_layers, batch_size, self.keep_prob)

        ### Run the data through the RNN layers
        # First, one-hot encode the input tokens
        x_one_hot = tf.one_hot(self.inputs, num_classes)
        
        # Run each sequence step through the RNN and collect the outputs
        outputs, state = tf.nn.dynamic_rnn(cell, x_one_hot, initial_state=self.initial_state)
        self.final_state = state
        
        # Get softmax predictions and logits
        self.prediction, self.logits = build_output(outputs, lstm_size, num_classes)
        
        # Loss and optimizer (with gradient clipping)
        self.loss = build_loss(self.logits, self.targets, lstm_size, num_classes)
        self.optimizer = build_optimizer(self.loss, learning_rate, grad_clip)

# %% [markdown]
# ## Hyperparameters
#
# Here I'm defining the hyperparameters for the network.
#
# * `batch_size` - Number of sequences running through the network in one pass.
# * `num_steps` - Number of characters in the sequence the network is trained on. Larger is better typically, the network will learn more long range dependencies. But it takes longer to train. 100 is typically a good number here.
# * `lstm_size` - The number of units in the hidden layers.
# * `num_layers` - Number of hidden LSTM layers to use
# * `learning_rate` - Learning rate for training
# * `keep_prob` - The dropout keep probability when training. If you're network is overfitting, try decreasing this.
#
# Here's some good advice from Andrej Karpathy on training the network. I'm going to copy it in here for your benefit, but also link to [where it originally came from](https://github.com/karpathy/char-rnn#tips-and-tricks).
#
# > ## Tips and Tricks
#
# >### Monitoring Validation Loss vs. Training Loss
# >If you're somewhat new to Machine Learning or Neural Networks it can take a bit of expertise to get good models. The most important quantity to keep track of is the difference between your training loss (printed during training) and the validation loss (printed once in a while when the RNN is run on the validation data (by default every 1000 iterations)). In particular:
#
# > - If your training loss is much lower than validation loss then this means the network might be **overfitting**. Solutions to this are to decrease your network size, or to increase dropout. For example you could try dropout of 0.5 and so on.
# > - If your training/validation loss are about equal then your model is **underfitting**. Increase the size of your model (either number of layers or the raw number of neurons per layer)
#
# > ### Approximate number of parameters
#
# > The two most important parameters that control the model are `lstm_size` and `num_layers`. I would advise that you always use `num_layers` of either 2/3. The `lstm_size` can be adjusted based on how much data you have. The two important quantities to keep track of here are:
#
# > - The number of parameters in your model. This is printed when you start training.
# > - The size of your dataset. 1MB file is approximately 1 million characters.
#
# >These two should be about the same order of magnitude. It's a little tricky to tell. Here are some examples:
#
# > - I have a 100MB dataset and I'm using the default parameter settings (which currently print 150K parameters). My data size is significantly larger (100 mil >> 0.15 mil), so I expect to heavily underfit. I am thinking I can comfortably afford to make `lstm_size` larger.
# > - I have a 10MB dataset and running a 10 million parameter model. I'm slightly nervous and I'm carefully monitoring my validation loss. If it's larger than my training loss then I may want to try to increase dropout a bit and see if that helps the validation loss.
#
# > ### Best models strategy
#
# >The winning strategy to obtaining very good models (if you have the compute time) is to always err on making the network larger (as large as you're willing to wait for it to compute) and then try different dropout values (between 0,1). Whatever model has the best validation performance (the loss, written in the checkpoint filename, low is good) is the one you should use in the end.
#
# >It is very common in deep learning to run many different models with many different hyperparameter settings, and in the end take whatever checkpoint gave the best validation performance.
#
# >By the way, the size of your training and validation splits are also parameters. Make sure you have a decent amount of data in your validation set or otherwise the validation performance will be noisy and not very informative.

# %%
batch_size = 100        # Sequences per batch
num_steps = 100         # Number of sequence steps per batch
lstm_size = 512         # Size of hidden layers in LSTMs
num_layers = 2          # Number of LSTM layers
learning_rate = 0.001   # Learning rate
keep_prob = 0.5         # Dropout keep probability

# %% [markdown]
# ## Time for training
#
# This is typical training code, passing inputs and targets into the network, then running the optimizer. Here we also get back the final LSTM state for the mini-batch. Then, we pass that state back into the network so the next batch can continue the state from the previous batch. And every so often (set by `save_every_n`) I save a checkpoint.
#
# Here I'm saving checkpoints with the format
#
# `i{iteration number}_l{# hidden layer units}.ckpt`

# %%
epochs = 20
# Save every N iterations
save_every_n = 200

model = CharRNN(len(vocab), batch_size=batch_size, num_steps=num_steps,
                lstm_size=lstm_size, num_layers=num_layers, 
                learning_rate=learning_rate)

saver = tf.train.Saver(max_to_keep=100)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    # Use the line below to load a checkpoint and resume training
    #saver.restore(sess, 'checkpoints/______.ckpt')
    counter = 0
    for e in range(epochs):
        # Train network
        new_state = sess.run(model.initial_state)
        loss = 0
        for x, y in get_batches(encoded, batch_size, num_steps):
            counter += 1
            start = time.time()
            feed = {model.inputs: x,
                    model.targets: y,
                    model.keep_prob: keep_prob,
                    model.initial_state: new_state}
            batch_loss, new_state, _ = sess.run([model.loss, 
                                                 model.final_state, 
                                                 model.optimizer], 
                                                 feed_dict=feed)
            
            end = time.time()
            print('Epoch: {}/{}... '.format(e+1, epochs),
                  'Training Step: {}... '.format(counter),
                  'Training loss: {:.4f}... '.format(batch_loss),
                  '{:.4f} sec/batch'.format((end-start)))
        
            if (counter % save_every_n == 0):
                saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
    
    saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
# Out:
# Epoch: 1/20...  Training Step: 1...  Training loss: 4.4164...  19.5073 sec/batch
# Epoch: 1/20...  Training Step: 2...  Training loss: 4.3107...  0.3675 sec/batch
# Epoch: 1/20...  Training Step: 3...  Training loss: 3.7654...  0.3168 sec/batch
# Epoch: 1/20...  Training Step: 4...  Training loss: 3.5848...  0.3051 sec/batch
# Epoch: 1/20...  Training Step: 5...  Training loss: 3.5450...  0.3050 sec/batch
# Epoch: 1/20...  Training Step: 6...  Training loss: 3.4671...  0.3054 sec/batch
# Epoch: 1/20...  Training Step: 7...  Training loss: 3.3903...  0.3054 sec/batch
# Epoch: 1/20...  Training Step: 8...  Training loss: 3.3365...  0.3054 sec/batch
# Epoch: 1/20...  Training Step: 9...  Training loss: 3.3289...  0.3042 sec/batch
# Epoch: 1/20...  Training Step: 10...  Training loss: 3.3131...  0.3050 sec/batch
# Epoch: 1/20...  Training Step: 11...  Training loss: 3.2753...  0.3053 sec/batch
# Epoch: 1/20...  Training Step: 12...  Training loss: 3.2716...  0.3047 sec/batch
# Epoch: 1/20...  Training Step: 13...  Training loss: 3.2510...  0.3047 sec/batch
# Epoch: 1/20...  Training Step: 14...  Training loss: 3.2732...  0.3045 sec/batch
# Epoch: 1/20...  Training Step: 15...  Training loss: 3.2484...  0.3051 sec/batch
# Epoch: 1/20...  Training Step: 16...  Training loss: 3.2399...  0.3056 sec/batch
# Epoch: 1/20...  Training Step: 17...  Training loss: 3.2282...  0.3045 sec/batch
# Epoch: 1/20...  Training Step: 18...  Training loss: 3.2462...  0.3050 sec/batch
# Epoch: 1/20...  Training Step: 19...  Training loss: 3.2270...  0.3050 sec/batch
# Epoch: 1/20...  Training Step: 20...  Training loss: 3.1818...  0.3056 sec/batch
# Epoch: 1/20...  Training Step: 21...  Training loss: 3.2050...  0.3045 sec/batch
# Epoch: 1/20...  Training Step: 22...  Training loss: 3.2106...  0.3052 sec/batch
# Epoch: 1/20...  Training Step: 23...  Training loss: 3.1900...  0.3056 sec/batch
# Epoch: 1/20...  Training Step: 24...  Training loss: 3.1992...  0.3055 sec/batch
# Epoch: 1/20...  Training Step: 25...  Training loss: 3.1873...  0.3054 sec/batch
# Epoch: 1/20...  Training Step: 26...  Training loss: 3.1929...  0.3054 sec/batch
# Epoch: 1/20...  Training Step: 27...  Training loss: 3.1999...  0.3054 sec/batch
# Epoch: 1/20...  Training Step: 28...  Training loss: 3.1701...  0.3050 sec/batch
# Epoch: 1/20...  Training Step: 29...  Training loss: 3.1730...  0.3057 sec/batch
# Epoch: 1/20...  Training Step: 30...  Training loss: 3.1841...  0.3052 sec/batch
# Epoch: 1/20...  Training Step: 31...  Training loss: 3.1978...  0.3054 sec/batch
# Epoch: 1/20...  Training Step: 32...  Training loss: 3.1619...  0.3047 sec/batch
# Epoch: 1/20...  Training Step: 33...  Training loss: 3.1572...  0.3052 sec/batch
# Epoch: 1/20...  Training Step: 34...  Training loss: 3.1807...  0.3052 sec/batch
# Epoch: 1/20...  Training Step: 35...  Training loss: 3.1492...  0.3057 sec/batch
# Epoch: 1/20...  Training Step: 36...  Training loss: 3.1664...  0.3046 sec/batch
# Epoch: 1/20...  Training Step: 37...  Training loss: 3.1372...  0.3048 sec/batch
# Epoch: 1/20...  Training Step: 38...  Training loss: 3.1403...  0.3049 sec/batch
# Epoch: 1/20...  Training Step: 39...  Training loss: 3.1374...  0.3059 sec/batch
# Epoch: 1/20...  Training Step: 40...  Training loss: 3.1324...  0.3049 sec/batch
# Epoch: 1/20...  Training Step: 41...  Training loss: 3.1260...  0.3049 sec/batch
# Epoch: 1/20...  Training Step: 42...  Training loss: 3.1388...  0.3054 sec/batch
# Epoch: 1/20...  Training Step: 43...  Training loss: 3.1217...  0.3053 sec/batch
# Epoch: 1/20...  Training Step: 44...  Training loss: 3.1208...  0.3050 sec/batch
# Epoch: 1/20...  Training Step: 45...  Training loss: 3.1213...  0.3055 sec/batch
# Epoch: 1/20...  Training Step: 46...  Training loss: 3.1302...  0.3057 sec/batch
# Epoch: 1/20...  Training Step: 47...  Training loss: 3.1365...  0.3059 sec/batch
# Epoch: 1/20...  Training Step: 48...  Training loss: 3.1401...  0.3046 sec/batch
# Epoch: 1/20...  Training Step: 49...  Training loss: 3.1278...  0.3053 sec/batch
# Epoch: 1/20...  Training Step: 50...  Training loss: 3.1237...  0.3053 sec/batch
# Epoch: 1/20...  Training Step: 51...  Training loss: 3.1083...  0.3049 sec/batch
# Epoch: 1/20...  Training Step: 52...  Training loss: 3.4988...  0.3052 sec/batch
# Epoch: 1/20...  Training Step: 53...  Training loss: 3.4872...  0.3050 sec/batch
# Epoch: 1/20...  Training Step: 54...  Training loss: 3.1173...  0.3055 sec/batch
# Epoch: 1/20...  Training Step: 55...  Training loss: 3.1197...  0.3057 sec/batch
# Epoch: 1/20...  Training Step: 56...  Training loss: 3.0966...  0.3053 sec/batch
# Epoch: 1/20...  Training Step: 57...  Training loss: 3.1101...  0.3046 sec/batch
# Epoch: 1/20...  Training Step: 58...  Training loss: 3.1103...  0.3047 sec/batch
# Epoch: 1/20...  Training Step: 59...  Training loss: 3.1007...  0.3047 sec/batch
# Epoch: 1/20...  Training Step: 60...  Training loss: 3.1065...  0.3050 sec/batch
# Epoch: 1/20...  Training Step: 61...  Training loss: 3.1102...  0.3056 sec/batch
# Epoch: 1/20...  Training Step: 62...  Training loss: 3.1197...  0.3047 sec/batch
# Epoch: 1/20...  Training Step: 63...  Training loss: 3.1370...  0.3052 sec/batch
# Epoch: 1/20...  Training Step: 64...  Training loss: 3.0846...  0.3054 sec/batch
# Epoch: 1/20...  Training Step: 65...  Training loss: 3.0872...  0.3051 sec/batch
# Epoch: 1/20...  Training Step: 66...  Training loss: 3.1126...  0.3054 sec/batch
# Epoch: 1/20...  Training Step: 67...  Training loss: 3.1071...  0.3054 sec/batch
# Epoch: 1/20...  Training Step: 68...  Training loss: 3.0575...  0.3055 sec/batch
# Epoch: 1/20...  Training Step: 69...  Training loss: 3.0766...  0.3053 sec/batch
# Epoch: 1/20...  Training Step: 70...  Training loss: 3.0889...  0.3051 sec/batch
# Epoch: 1/20...  Training Step: 71...  Training loss: 3.0766...  0.3057 sec/batch
# Epoch: 1/20...  Training Step: 72...  Training loss: 3.0950...  0.3051 sec/batch
# Epoch: 1/20...  Training Step: 73...  Training loss: 3.0740...  0.3054 sec/batch
# Epoch: 1/20...  Training Step: 74...  Training loss: 3.0761...  0.3055 sec/batch
# Epoch: 1/20...  Training Step: 75...  Training loss: 3.0816...  0.3058 sec/batch
# Epoch: 1/20...  Training Step: 76...  Training loss: 3.0821...  0.3052 sec/batch
# Epoch: 1/20...  Training Step: 77...  Training loss: 3.0752...  0.3051 sec/batch
# Epoch: 1/20...  Training Step: 78...  Training loss: 3.0643...  0.3052 sec/batch
# Epoch: 1/20...  Training Step: 79...  Training loss: 3.0584...  0.3051 sec/batch
# Epoch: 1/20...  Training Step: 80...  Training loss: 3.0424...  0.3050 sec/batch
# Epoch: 1/20...  Training Step: 81...  Training loss: 3.0451...  0.3050 sec/batch
# Epoch: 1/20...  Training Step: 82...  Training loss: 3.0513...  0.3055 sec/batch
# Epoch: 1/20...  Training Step: 83...  Training loss: 3.0470...  0.3050 sec/batch
# Epoch: 1/20...  Training Step: 84...  Training loss: 3.0211...  0.3062 sec/batch
# Epoch: 1/20...  Training Step: 85...  Training loss: 3.0031...  0.3057 sec/batch
# Epoch: 1/20...  Training Step: 86...  Training loss: 3.0105...  0.3059 sec/batch
# Epoch: 1/20...  Training Step: 87...  Training loss: 2.9952...  0.3049 sec/batch
# Epoch: 1/20...  Training Step: 88...  Training loss: 3.0063...  0.3055 sec/batch
# Epoch: 1/20...  Training Step: 89...  Training loss: 3.0318...  0.3054 sec/batch
# Epoch: 1/20...  Training Step: 90...  Training loss: 3.0302...  0.3056 sec/batch
# Epoch: 1/20...  Training Step: 91...  Training loss: 3.0079...  0.3057 sec/batch
# Epoch: 1/20...  Training Step: 92...  Training loss: 3.0017...  0.3057 sec/batch
# Epoch: 1/20...  Training Step: 93...  Training loss: 3.0071...  0.3054 sec/batch
# Epoch: 1/20...  Training Step: 94...  Training loss: 3.0044...  0.3054 sec/batch
# Epoch: 1/20...  Training Step: 95...  Training loss: 2.9771...  0.3051 sec/batch
# Epoch: 1/20...  Training Step: 96...  Training loss: 2.9745...  0.3057 sec/batch
# Epoch: 1/20...  Training Step: 97...  Training loss: 2.9764...  0.3062 sec/batch
# Epoch: 1/20...  Training Step: 98...  Training loss: 2.9561...  0.3056 sec/batch
# Epoch: 1/20...  Training Step: 99...  Training loss: 2.9611...  0.3056 sec/batch
# Epoch: 1/20...  Training Step: 100...  Training loss: 2.9428...  0.3054 sec/batch
# Epoch: 1/20...  Training Step: 101...  Training loss: 2.9382...  0.3054 sec/batch
# Epoch: 1/20...  Training Step: 102...  Training loss: 2.9161...  0.3054 sec/batch
# Epoch: 1/20...  Training Step: 103...  Training loss: 2.9114...  0.3058 sec/batch
# Epoch: 1/20...  Training Step: 104...  Training loss: 2.8971...  0.3064 sec/batch
# Epoch: 1/20...  Training Step: 105...  Training loss: 2.8826...  0.3070 sec/batch
# Epoch: 1/20...  Training Step: 106...  Training loss: 2.8879...  0.3057 sec/batch
# Epoch: 1/20...  Training Step: 107...  Training loss: 2.8425...  0.3049 sec/batch
# Epoch: 1/20...  Training Step: 108...  Training loss: 2.8666...  0.3073 sec/batch
# Epoch: 1/20...  Training Step: 109...  Training loss: 2.8669...  0.3077 sec/batch
# Epoch: 1/20...  Training Step: 110...  Training loss: 2.8175...  0.3058 sec/batch
# Epoch: 1/20...  Training Step: 111...  Training loss: 2.8198...  0.3058 sec/batch
# Epoch: 1/20...  Training Step: 112...  Training loss: 2.8320...  0.3057 sec/batch
# Epoch: 1/20...  Training Step: 113...  Training loss: 2.8088...  0.3055 sec/batch
# Epoch: 1/20...  Training Step: 114...  Training loss: 2.7847...  0.3054 sec/batch
# Epoch: 1/20...  Training Step: 115...  Training loss: 2.7875...  0.3064 sec/batch
# Epoch: 1/20...  Training Step: 116...  Training loss: 2.7584...  0.3055 sec/batch
# Epoch: 1/20...  Training Step: 117...  Training loss: 2.7585...  0.3062 sec/batch
# Epoch: 1/20...  Training Step: 118...  Training loss: 2.7593...  0.3059 sec/batch
# Epoch: 1/20...  Training Step: 119...  Training loss: 2.7718...  0.3053 sec/batch
# Epoch: 1/20...  Training Step: 120...  Training loss: 2.7427...  0.3098 sec/batch
# Epoch: 1/20...  Training Step: 121...  Training loss: 2.7575...  0.3065 sec/batch
# Epoch: 1/20...  Training Step: 122...  Training loss: 2.7226...  0.3060 sec/batch
# Epoch: 1/20...  Training Step: 123...  Training loss: 2.7063...  0.3084 sec/batch
# Epoch: 1/20...  Training Step: 124...  Training loss: 2.7239...  0.3062 sec/batch
# Epoch: 1/20...  Training Step: 125...  Training loss: 2.6951...  0.3056 sec/batch
# Epoch: 1/20...  Training Step: 126...  Training loss: 2.6599...  0.3076 sec/batch
# Epoch: 1/20...  Training Step: 127...  Training loss: 2.6818...  0.3070 sec/batch
# Epoch: 1/20...  Training Step: 128...  Training loss: 2.6849...  0.3054 sec/batch
# Epoch: 1/20...  Training Step: 129...  Training loss: 2.6545...  0.3055 sec/batch
# Epoch: 1/20...  Training Step: 130...  Training loss: 2.6379...  0.3058 sec/batch
# Epoch: 1/20...  Training Step: 131...  Training loss: 2.6401...  0.3083 sec/batch
# Epoch: 1/20...  Training Step: 132...  Training loss: 2.6087...  0.3072 sec/batch
# Epoch: 1/20...  Training Step: 133...  Training loss: 2.6299...  0.3060 sec/batch
# Epoch: 1/20...  Training Step: 134...  Training loss: 2.6186...  0.3060 sec/batch
# Epoch: 1/20...  Training Step: 135...  Training loss: 2.5881...  0.3063 sec/batch
# Epoch: 1/20...  Training Step: 136...  Training loss: 2.5891...  0.3084 sec/batch
# Epoch: 1/20...  Training Step: 137...  Training loss: 2.5749...  0.3078 sec/batch
# Epoch: 1/20...  Training Step: 138...  Training loss: 2.5905...  0.3060 sec/batch
# Epoch: 1/20...  Training Step: 139...  Training loss: 2.5860...  0.3057 sec/batch
# Epoch: 1/20...  Training Step: 140...  Training loss: 2.5679...  0.3073 sec/batch
# Epoch: 1/20...  Training Step: 141...  Training loss: 2.5880...  0.3071 sec/batch
# Epoch: 1/20...  Training Step: 142...  Training loss: 2.5326...  0.3056 sec/batch
# Epoch: 1/20...  Training Step: 143...  Training loss: 2.5655...  0.3079 sec/batch
# Epoch: 1/20...  Training Step: 144...  Training loss: 2.5476...  0.3075 sec/batch
# Epoch: 1/20...  Training Step: 145...  Training loss: 2.5378...  0.3069 sec/batch
# Epoch: 1/20...  Training Step: 146...  Training loss: 2.5552...  0.3054 sec/batch
# Epoch: 1/20...  Training Step: 147...  Training loss: 2.5419...  0.3055 sec/batch
# Epoch: 1/20...  Training Step: 148...  Training loss: 2.5595...  0.3057 sec/batch
# Epoch: 1/20...  Training Step: 149...  Training loss: 2.5126...  0.3060 sec/batch
# Epoch: 1/20...  Training Step: 150...  Training loss: 2.5149...  0.3057 sec/batch
# Epoch: 1/20...  Training Step: 151...  Training loss: 2.5610...  0.3082 sec/batch
# Epoch: 1/20...  Training Step: 152...  Training loss: 2.5663...  0.3087 sec/batch
# Epoch: 1/20...  Training Step: 153...  Training loss: 2.5271...  0.3062 sec/batch
# Epoch: 1/20...  Training Step: 154...  Training loss: 2.5246...  0.3086 sec/batch
# Epoch: 1/20...  Training Step: 155...  Training loss: 2.5000...  0.3085 sec/batch
# Epoch: 1/20...  Training Step: 156...  Training loss: 2.4949...  0.3096 sec/batch
# Epoch: 1/20...  Training Step: 157...  Training loss: 2.4811...  0.3056 sec/batch
# Epoch: 1/20...  Training Step: 158...  Training loss: 2.4878...  0.3052 sec/batch
# Epoch: 1/20...  Training Step: 159...  Training loss: 2.4564...  0.3089 sec/batch
# Epoch: 1/20...  Training Step: 160...  Training loss: 2.5111...  0.3078 sec/batch
# Epoch: 1/20...  Training Step: 161...  Training loss: 2.4813...  0.3071 sec/batch
# Epoch: 1/20...  Training Step: 162...  Training loss: 2.4534...  0.3088 sec/batch
# Epoch: 1/20...  Training Step: 163...  Training loss: 2.4461...  0.3072 sec/batch
# Epoch: 1/20...  Training Step: 164...  Training loss: 2.4623...  0.3055 sec/batch
# Epoch: 1/20...  Training Step: 165...  Training loss: 2.4762...  0.3094 sec/batch
# Epoch: 1/20...  Training Step: 166...  Training loss: 2.4646...  0.3079 sec/batch
# Epoch: 1/20...  Training Step: 167...  Training loss: 2.4690...  0.3088 sec/batch
# Epoch: 1/20...  Training Step: 168...  Training loss: 2.4573...  0.3087 sec/batch
# Epoch: 1/20...  Training Step: 169...  Training loss: 2.4507...  0.3066 sec/batch
# Epoch: 1/20...  Training Step: 170...  Training loss: 2.4301...  0.3095 sec/batch
# Epoch: 1/20...  Training Step: 171...  Training loss: 2.4531...  0.3072 sec/batch
# Epoch: 1/20...  Training Step: 172...  Training loss: 2.4641...  0.3057 sec/batch
# Epoch: 1/20...  Training Step: 173...  Training loss: 2.4740...  0.3061 sec/batch
# Epoch: 1/20...  Training Step: 174...  Training loss: 2.4654...  0.3102 sec/batch
# Epoch: 1/20...  Training Step: 175...  Training loss: 2.4804...  0.3073 sec/batch
# Epoch: 1/20...  Training Step: 176...  Training loss: 2.4399...  0.3057 sec/batch
# Epoch: 1/20...  Training Step: 177...  Training loss: 2.4361...  0.3065 sec/batch
# Epoch: 1/20...  Training Step: 178...  Training loss: 2.4098...  0.3114 sec/batch
# Epoch: 1/20...  Training Step: 179...  Training loss: 2.4070...  0.3098 sec/batch
# Epoch: 1/20...  Training Step: 180...  Training loss: 2.4005...  0.3096 sec/batch
# Epoch: 1/20...  Training Step: 181...  Training loss: 2.4080...  0.3088 sec/batch
# Epoch: 1/20...  Training Step: 182...  Training loss: 2.4146...  0.3053 sec/batch
# Epoch: 1/20...  Training Step: 183...  Training loss: 2.3938...  0.3061 sec/batch
# Epoch: 1/20...  Training Step: 184...  Training loss: 2.4323...  0.3095 sec/batch
# Epoch: 1/20...  Training Step: 185...  Training loss: 2.4502...  0.3076 sec/batch
# Epoch: 1/20...  Training Step: 186...  Training loss: 2.4069...  0.3079 sec/batch
# Epoch: 1/20...  Training Step: 187...  Training loss: 2.3880...  0.3067 sec/batch
# Epoch: 1/20...  Training Step: 188...  Training loss: 2.3768...  0.3072 sec/batch
# Epoch: 1/20...  Training Step: 189...  Training loss: 2.3814...  0.3097 sec/batch
# Epoch: 1/20...  Training Step: 190...  Training loss: 2.3835...  0.3099 sec/batch
# Epoch: 1/20...  Training Step: 191...  Training loss: 2.3959...  0.3095 sec/batch
# Epoch: 1/20...  Training Step: 192...  Training loss: 2.3594...  0.3095 sec/batch
# Epoch: 1/20...  Training Step: 193...  Training loss: 2.3839...  0.3096 sec/batch
# Epoch: 1/20...  Training Step: 194...  Training loss: 2.3678...  0.3095 sec/batch
# Epoch: 1/20...  Training Step: 195...  Training loss: 2.3714...  0.3087 sec/batch
# Epoch: 1/20...  Training Step: 196...  Training loss: 2.3634...  0.3073 sec/batch
# Epoch: 1/20...  Training Step: 197...  Training loss: 2.3520...  0.3078 sec/batch
# Epoch: 1/20...  Training Step: 198...  Training loss: 2.3581...  0.3078 sec/batch
# Epoch: 2/20...  Training Step: 199...  Training loss: 2.4398...  0.3067 sec/batch
# Epoch: 2/20...  Training Step: 200...  Training loss: 2.3324...  0.3077 sec/batch
# Epoch: 2/20...  Training Step: 201...  Training loss: 2.3432...  0.3087 sec/batch
# Epoch: 2/20...  Training Step: 202...  Training loss: 2.3555...  0.3066 sec/batch
# Epoch: 2/20...  Training Step: 203...  Training loss: 2.3460...  0.3068 sec/batch
# Epoch: 2/20...  Training Step: 204...  Training loss: 2.3520...  0.3091 sec/batch
# Epoch: 2/20...  Training Step: 205...  Training loss: 2.3430...  0.3091 sec/batch
# Epoch: 2/20...  Training Step: 206...  Training loss: 2.3461...  0.3094 sec/batch
# Epoch: 2/20...  Training Step: 207...  Training loss: 2.3730...  0.3093 sec/batch
# Epoch: 2/20...  Training Step: 208...  Training loss: 2.3403...  0.3094 sec/batch
# Epoch: 2/20...  Training Step: 209...  Training loss: 2.3281...  0.3093 sec/batch
# Epoch: 2/20...  Training Step: 210...  Training loss: 2.3375...  0.3088 sec/batch
# Epoch: 2/20...  Training Step: 211...  Training loss: 2.3386...  0.3112 sec/batch
# Epoch: 2/20...  Training Step: 212...  Training loss: 2.3575...  0.3099 sec/batch
# Epoch: 2/20...  Training Step: 213...  Training loss: 2.3394...  0.3086 sec/batch
# Epoch: 2/20...  Training Step: 214...  Training loss: 2.3246...  0.3073 sec/batch
# Epoch: 2/20...  Training Step: 215...  Training loss: 2.3284...  0.3092 sec/batch
# Epoch: 2/20...  Training Step: 216...  Training loss: 2.3566...  0.3097 sec/batch
# Epoch: 2/20...  Training Step: 217...  Training loss: 2.3274...  0.3095 sec/batch
# Epoch: 2/20...  Training Step: 218...  Training loss: 2.3037...  0.3094 sec/batch
# Epoch: 2/20...  Training Step: 219...  Training loss: 2.3152...  0.3098 sec/batch
# Epoch: 2/20...  Training Step: 220...  Training loss: 2.3466...  0.3098 sec/batch
# Epoch: 2/20...  Training Step: 221...  Training loss: 2.3152...  0.3098 sec/batch
# Epoch: 2/20...  Training Step: 222...  Training loss: 2.3011...  0.3083 sec/batch
# Epoch: 2/20...  Training Step: 223...  Training loss: 2.3032...  0.3070 sec/batch
# Epoch: 2/20...  Training Step: 224...  Training loss: 2.3055...  0.3097 sec/batch
# Epoch: 2/20...  Training Step: 225...  Training loss: 2.2784...  0.3072 sec/batch
# Epoch: 2/20...  Training Step: 226...  Training loss: 2.2978...  0.3063 sec/batch
# Epoch: 2/20...  Training Step: 227...  Training loss: 2.3151...  0.3096 sec/batch
# Epoch: 2/20...  Training Step: 228...  Training loss: 2.3147...  0.3075 sec/batch
# Epoch: 2/20...  Training Step: 229...  Training loss: 2.3016...  0.3098 sec/batch
# Epoch: 2/20...  Training Step: 230...  Training loss: 2.2681...  0.3097 sec/batch
# Epoch: 2/20...  Training Step: 231...  Training loss: 2.2692...  0.3096 sec/batch
# Epoch: 2/20...  Training Step: 232...  Training loss: 2.2979...  0.3094 sec/batch
# Epoch: 2/20...  Training Step: 233...  Training loss: 2.2679...  0.3093 sec/batch
# Epoch: 2/20...  Training Step: 234...  Training loss: 2.2805...  0.3097 sec/batch
# Epoch: 2/20...  Training Step: 235...  Training loss: 2.2798...  0.3098 sec/batch
# Epoch: 2/20...  Training Step: 236...  Training loss: 2.2514...  0.3095 sec/batch
# Epoch: 2/20...  Training Step: 237...  Training loss: 2.2463...  0.3085 sec/batch
# Epoch: 2/20...  Training Step: 238...  Training loss: 2.2421...  0.3094 sec/batch
# Epoch: 2/20...  Training Step: 239...  Training loss: 2.2482...  0.3093 sec/batch
# Epoch: 2/20...  Training Step: 240...  Training loss: 2.2489...  0.3091 sec/batch
# Epoch: 2/20...  Training Step: 241...  Training loss: 2.2362...  0.3093 sec/batch
# Epoch: 2/20...  Training Step: 242...  Training loss: 2.2319...  0.3095 sec/batch
# Epoch: 2/20...  Training Step: 243...  Training loss: 2.2451...  0.3094 sec/batch
# Epoch: 2/20...  Training Step: 244...  Training loss: 2.1916...  0.3099 sec/batch
# Epoch: 2/20...  Training Step: 245...  Training loss: 2.2564...  0.3100 sec/batch
# Epoch: 2/20...  Training Step: 246...  Training loss: 2.2369...  0.3089 sec/batch
# Epoch: 2/20...  Training Step: 247...  Training loss: 2.2319...  0.3089 sec/batch
# Epoch: 2/20...  Training Step: 248...  Training loss: 2.2744...  0.3073 sec/batch
# Epoch: 2/20...  Training Step: 249...  Training loss: 2.2116...  0.3096 sec/batch
# Epoch: 2/20...  Training Step: 250...  Training loss: 2.2654...  0.3099 sec/batch
# Epoch: 2/20...  Training Step: 251...  Training loss: 2.2249...  0.3093 sec/batch
# Epoch: 2/20...  Training Step: 252...  Training loss: 2.2215...  0.3097 sec/batch
# Epoch: 2/20...  Training Step: 253...  Training loss: 2.2177...  0.3098 sec/batch
# Epoch: 2/20...  Training Step: 254...  Training loss: 2.2360...  0.3092 sec/batch
# Epoch: 2/20...  Training Step: 255...  Training loss: 2.2267...  0.3094 sec/batch
# Epoch: 2/20...  Training Step: 256...  Training loss: 2.2141...  0.3096 sec/batch
# Epoch: 2/20...  Training Step: 257...  Training loss: 2.2023...  0.3100 sec/batch
# Epoch: 2/20...  Training Step: 258...  Training loss: 2.2477...  0.3086 sec/batch
# Epoch: 2/20...  Training Step: 259...  Training loss: 2.2164...  0.3093 sec/batch
# Epoch: 2/20...  Training Step: 260...  Training loss: 2.2348...  0.3096 sec/batch
# Epoch: 2/20...  Training Step: 261...  Training loss: 2.2377...  0.3092 sec/batch
# Epoch: 2/20...  Training Step: 262...  Training loss: 2.2073...  0.3102 sec/batch
# Epoch: 2/20...  Training Step: 263...  Training loss: 2.1894...  0.3093 sec/batch
# Epoch: 2/20...  Training Step: 264...  Training loss: 2.2256...  0.3090 sec/batch
# Epoch: 2/20...  Training Step: 265...  Training loss: 2.2033...  0.3101 sec/batch
# Epoch: 2/20...  Training Step: 266...  Training loss: 2.1798...  0.3092 sec/batch
# Epoch: 2/20...  Training Step: 267...  Training loss: 2.1786...  0.3092 sec/batch
# Epoch: 2/20...  Training Step: 268...  Training loss: 2.1927...  0.3094 sec/batch
# Epoch: 2/20...  Training Step: 269...  Training loss: 2.2163...  0.3092 sec/batch
# Epoch: 2/20...  Training Step: 270...  Training loss: 2.1978...  0.3100 sec/batch
# Epoch: 2/20...  Training Step: 271...  Training loss: 2.1965...  0.3092 sec/batch
# Epoch: 2/20...  Training Step: 272...  Training loss: 2.1708...  0.3104 sec/batch
# Epoch: 2/20...  Training Step: 273...  Training loss: 2.1826...  0.3096 sec/batch
# Epoch: 2/20...  Training Step: 274...  Training loss: 2.2170...  0.3096 sec/batch
# Epoch: 2/20...  Training Step: 275...  Training loss: 2.1786...  0.3092 sec/batch
# Epoch: 2/20...  Training Step: 276...  Training loss: 2.1904...  0.3093 sec/batch
# Epoch: 2/20...  Training Step: 277...  Training loss: 2.1572...  0.3098 sec/batch
# Epoch: 2/20...  Training Step: 278...  Training loss: 2.1633...  0.3097 sec/batch
# Epoch: 2/20...  Training Step: 279...  Training loss: 2.1438...  0.3096 sec/batch
# Epoch: 2/20...  Training Step: 280...  Training loss: 2.1863...  0.3097 sec/batch
# Epoch: 2/20...  Training Step: 281...  Training loss: 2.1445...  0.3091 sec/batch
# Epoch: 2/20...  Training Step: 282...  Training loss: 2.1432...  0.3093 sec/batch
# Epoch: 2/20...  Training Step: 283...  Training loss: 2.1224...  0.3092 sec/batch
# Epoch: 2/20...  Training Step: 284...  Training loss: 2.1423...  0.3115 sec/batch
# Epoch: 2/20...  Training Step: 285...  Training loss: 2.1543...  0.3095 sec/batch
# Epoch: 2/20...  Training Step: 286...  Training loss: 2.1445...  0.3099 sec/batch
# Epoch: 2/20...  Training Step: 287...  Training loss: 2.1316...  0.3095 sec/batch
# Epoch: 2/20...  Training Step: 288...  Training loss: 2.1634...  0.3091 sec/batch
# Epoch: 2/20...  Training Step: 289...  Training loss: 2.1234...  0.3093 sec/batch
# Epoch: 2/20...  Training Step: 290...  Training loss: 2.1434...  0.3095 sec/batch
# Epoch: 2/20...  Training Step: 291...  Training loss: 2.1182...  0.3098 sec/batch
# Epoch: 2/20...  Training Step: 292...  Training loss: 2.1238...  0.3094 sec/batch
# Epoch: 2/20...  Training Step: 293...  Training loss: 2.1158...  0.3096 sec/batch
# Epoch: 2/20...  Training Step: 294...  Training loss: 2.1283...  0.3100 sec/batch
# Epoch: 2/20...  Training Step: 295...  Training loss: 2.1296...  0.3096 sec/batch
# Epoch: 2/20...  Training Step: 296...  Training loss: 2.1336...  0.3095 sec/batch
# Epoch: 2/20...  Training Step: 297...  Training loss: 2.1061...  0.3116 sec/batch
# Epoch: 2/20...  Training Step: 298...  Training loss: 2.0966...  0.3106 sec/batch
# Epoch: 2/20...  Training Step: 299...  Training loss: 2.1345...  0.3096 sec/batch
# Epoch: 2/20...  Training Step: 300...  Training loss: 2.1292...  0.3091 sec/batch
# Epoch: 2/20...  Training Step: 301...  Training loss: 2.1118...  0.3093 sec/batch
# Epoch: 2/20...  Training Step: 302...  Training loss: 2.1150...  0.3096 sec/batch
# Epoch: 2/20...  Training Step: 303...  Training loss: 2.1043...  0.3084 sec/batch
# Epoch: 2/20...  Training Step: 304...  Training loss: 2.1221...  0.3091 sec/batch
# Epoch: 2/20...  Training Step: 305...  Training loss: 2.1045...  0.3096 sec/batch
# Epoch: 2/20...  Training Step: 306...  Training loss: 2.1327...  0.3119 sec/batch
# Epoch: 2/20...  Training Step: 307...  Training loss: 2.1341...  0.3096 sec/batch
# Epoch: 2/20...  Training Step: 308...  Training loss: 2.0985...  0.3107 sec/batch
# Epoch: 2/20...  Training Step: 309...  Training loss: 2.1130...  0.3099 sec/batch
# Epoch: 2/20...  Training Step: 310...  Training loss: 2.1127...  0.3093 sec/batch
# Epoch: 2/20...  Training Step: 311...  Training loss: 2.1184...  0.3092 sec/batch
# Epoch: 2/20...  Training Step: 312...  Training loss: 2.0972...  0.3100 sec/batch
# Epoch: 2/20...  Training Step: 313...  Training loss: 2.0969...  0.3104 sec/batch
# Epoch: 2/20...  Training Step: 314...  Training loss: 2.0572...  0.3098 sec/batch
# Epoch: 2/20...  Training Step: 315...  Training loss: 2.1074...  0.3095 sec/batch
# Epoch: 2/20...  Training Step: 316...  Training loss: 2.0998...  0.3094 sec/batch
# Epoch: 2/20...  Training Step: 317...  Training loss: 2.1061...  0.3114 sec/batch
# Epoch: 2/20...  Training Step: 318...  Training loss: 2.1008...  0.3090 sec/batch
# Epoch: 2/20...  Training Step: 319...  Training loss: 2.1091...  0.3098 sec/batch
# Epoch: 2/20...  Training Step: 320...  Training loss: 2.0704...  0.3092 sec/batch
# Epoch: 2/20...  Training Step: 321...  Training loss: 2.0803...  0.3097 sec/batch
# Epoch: 2/20...  Training Step: 322...  Training loss: 2.1184...  0.3097 sec/batch
# Epoch: 2/20...  Training Step: 323...  Training loss: 2.0674...  0.3094 sec/batch
# Epoch: 2/20...  Training Step: 324...  Training loss: 2.0438...  0.3093 sec/batch
# Epoch: 2/20...  Training Step: 325...  Training loss: 2.0911...  0.3091 sec/batch
# Epoch: 2/20...  Training Step: 326...  Training loss: 2.0982...  0.3097 sec/batch
# Epoch: 2/20...  Training Step: 327...  Training loss: 2.0788...  0.3095 sec/batch
# Epoch: 2/20...  Training Step: 328...  Training loss: 2.0837...  0.3109 sec/batch
# Epoch: 2/20...  Training Step: 329...  Training loss: 2.0658...  0.3115 sec/batch
# Epoch: 2/20...  Training Step: 330...  Training loss: 2.0542...  0.3099 sec/batch
# Epoch: 2/20...  Training Step: 331...  Training loss: 2.0967...  0.3095 sec/batch
# Epoch: 2/20...  Training Step: 332...  Training loss: 2.0894...  0.3096 sec/batch
# Epoch: 2/20...  Training Step: 333...  Training loss: 2.0773...  0.3094 sec/batch
# Epoch: 2/20...  Training Step: 334...  Training loss: 2.0877...  0.3101 sec/batch
# Epoch: 2/20...  Training Step: 335...  Training loss: 2.0797...  0.3094 sec/batch
# Epoch: 2/20...  Training Step: 336...  Training loss: 2.0701...  0.3117 sec/batch
# Epoch: 2/20...  Training Step: 337...  Training loss: 2.1138...  0.3097 sec/batch
# Epoch: 2/20...  Training Step: 338...  Training loss: 2.0582...  0.3105 sec/batch
# Epoch: 2/20...  Training Step: 339...  Training loss: 2.0906...  0.3117 sec/batch
# Epoch: 2/20...  Training Step: 340...  Training loss: 2.0574...  0.3096 sec/batch
# Epoch: 2/20...  Training Step: 341...  Training loss: 2.0606...  0.3099 sec/batch
# Epoch: 2/20...  Training Step: 342...  Training loss: 2.0627...  0.3095 sec/batch
# Epoch: 2/20...  Training Step: 343...  Training loss: 2.0448...  0.3097 sec/batch
# Epoch: 2/20...  Training Step: 344...  Training loss: 2.0793...  0.3098 sec/batch
# Epoch: 2/20...  Training Step: 345...  Training loss: 2.0702...  0.3095 sec/batch
# Epoch: 2/20...  Training Step: 346...  Training loss: 2.0790...  0.3101 sec/batch
# Epoch: 2/20...  Training Step: 347...  Training loss: 2.0560...  0.3123 sec/batch
# Epoch: 2/20...  Training Step: 348...  Training loss: 2.0459...  0.3106 sec/batch
# Epoch: 2/20...  Training Step: 349...  Training loss: 2.0535...  0.3101 sec/batch
# Epoch: 2/20...  Training Step: 350...  Training loss: 2.0989...  0.3116 sec/batch
# Epoch: 2/20...  Training Step: 351...  Training loss: 2.0532...  0.3102 sec/batch
# Epoch: 2/20...  Training Step: 352...  Training loss: 2.0598...  0.3092 sec/batch
# Epoch: 2/20...  Training Step: 353...  Training loss: 2.0404...  0.3100 sec/batch
# Epoch: 2/20...  Training Step: 354...  Training loss: 2.0376...  0.3100 sec/batch
# Epoch: 2/20...  Training Step: 355...  Training loss: 2.0382...  0.3094 sec/batch
# Epoch: 2/20...  Training Step: 356...  Training loss: 2.0400...  0.3101 sec/batch
# Epoch: 2/20...  Training Step: 357...  Training loss: 2.0100...  0.3097 sec/batch
# Epoch: 2/20...  Training Step: 358...  Training loss: 2.0773...  0.3115 sec/batch
# Epoch: 2/20...  Training Step: 359...  Training loss: 2.0522...  0.3097 sec/batch
# Epoch: 2/20...  Training Step: 360...  Training loss: 2.0229...  0.3097 sec/batch
# Epoch: 2/20...  Training Step: 361...  Training loss: 2.0405...  0.3101 sec/batch
# Epoch: 2/20...  Training Step: 362...  Training loss: 2.0426...  0.3097 sec/batch
# Epoch: 2/20...  Training Step: 363...  Training loss: 2.0293...  0.3101 sec/batch
# Epoch: 2/20...  Training Step: 364...  Training loss: 2.0168...  0.3095 sec/batch
# Epoch: 2/20...  Training Step: 365...  Training loss: 2.0383...  0.3102 sec/batch
# Epoch: 2/20...  Training Step: 366...  Training loss: 2.0605...  0.3096 sec/batch
# Epoch: 2/20...  Training Step: 367...  Training loss: 2.0234...  0.3122 sec/batch
# Epoch: 2/20...  Training Step: 368...  Training loss: 2.0178...  0.3123 sec/batch
# Epoch: 2/20...  Training Step: 369...  Training loss: 2.0130...  0.3118 sec/batch
# Epoch: 2/20...  Training Step: 370...  Training loss: 2.0313...  0.3113 sec/batch
# Epoch: 2/20...  Training Step: 371...  Training loss: 2.0595...  0.3097 sec/batch
# Epoch: 2/20...  Training Step: 372...  Training loss: 2.0438...  0.3103 sec/batch
# Epoch: 2/20...  Training Step: 373...  Training loss: 2.0383...  0.3108 sec/batch
# Epoch: 2/20...  Training Step: 374...  Training loss: 2.0203...  0.3093 sec/batch
# Epoch: 2/20...  Training Step: 375...  Training loss: 2.0039...  0.3098 sec/batch
# Epoch: 2/20...  Training Step: 376...  Training loss: 2.0172...  0.3099 sec/batch
# Epoch: 2/20...  Training Step: 377...  Training loss: 1.9932...  0.3111 sec/batch
# Epoch: 2/20...  Training Step: 378...  Training loss: 1.9691...  0.3111 sec/batch
# Epoch: 2/20...  Training Step: 379...  Training loss: 1.9855...  0.3095 sec/batch
# Epoch: 2/20...  Training Step: 380...  Training loss: 2.0053...  0.3096 sec/batch
# Epoch: 2/20...  Training Step: 381...  Training loss: 2.0095...  0.3096 sec/batch
# Epoch: 2/20...  Training Step: 382...  Training loss: 2.0288...  0.3103 sec/batch
# Epoch: 2/20...  Training Step: 383...  Training loss: 2.0097...  0.3099 sec/batch
# Epoch: 2/20...  Training Step: 384...  Training loss: 1.9993...  0.3103 sec/batch
# Epoch: 2/20...  Training Step: 385...  Training loss: 2.0005...  0.3111 sec/batch
# Epoch: 2/20...  Training Step: 386...  Training loss: 1.9820...  0.3099 sec/batch
# Epoch: 2/20...  Training Step: 387...  Training loss: 1.9890...  0.3093 sec/batch
# Epoch: 2/20...  Training Step: 388...  Training loss: 1.9856...  0.3123 sec/batch
# Epoch: 2/20...  Training Step: 389...  Training loss: 2.0065...  0.3123 sec/batch
# Epoch: 2/20...  Training Step: 390...  Training loss: 1.9645...  0.3112 sec/batch
# Epoch: 2/20...  Training Step: 391...  Training loss: 1.9960...  0.3092 sec/batch
# Epoch: 2/20...  Training Step: 392...  Training loss: 1.9774...  0.3099 sec/batch
# Epoch: 2/20...  Training Step: 393...  Training loss: 1.9560...  0.3104 sec/batch
# Epoch: 2/20...  Training Step: 394...  Training loss: 1.9931...  0.3095 sec/batch
# Epoch: 2/20...  Training Step: 395...  Training loss: 1.9828...  0.3100 sec/batch
# Epoch: 2/20...  Training Step: 396...  Training loss: 1.9695...  0.3098 sec/batch
# Epoch: 3/20...  Training Step: 397...  Training loss: 2.0624...  0.3119 sec/batch
# Epoch: 3/20...  Training Step: 398...  Training loss: 1.9606...  0.3122 sec/batch
# Epoch: 3/20...  Training Step: 399...  Training loss: 1.9592...  0.3112 sec/batch
# Epoch: 3/20...  Training Step: 400...  Training loss: 1.9637...  0.3103 sec/batch
# Epoch: 3/20...  Training Step: 401...  Training loss: 1.9685...  0.3095 sec/batch
# Epoch: 3/20...  Training Step: 402...  Training loss: 1.9256...  0.3073 sec/batch
# Epoch: 3/20...  Training Step: 403...  Training loss: 1.9632...  0.3127 sec/batch
# Epoch: 3/20...  Training Step: 404...  Training loss: 1.9552...  0.3129 sec/batch
# Epoch: 3/20...  Training Step: 405...  Training loss: 1.9973...  0.3125 sec/batch
# Epoch: 3/20...  Training Step: 406...  Training loss: 1.9538...  0.3121 sec/batch
# Epoch: 3/20...  Training Step: 407...  Training loss: 1.9401...  0.3107 sec/batch
# Epoch: 3/20...  Training Step: 408...  Training loss: 1.9356...  0.3099 sec/batch
# Epoch: 3/20...  Training Step: 409...  Training loss: 1.9583...  0.3104 sec/batch
# Epoch: 3/20...  Training Step: 410...  Training loss: 1.9990...  0.3122 sec/batch
# Epoch: 3/20...  Training Step: 411...  Training loss: 1.9534...  0.3110 sec/batch
# Epoch: 3/20...  Training Step: 412...  Training loss: 1.9328...  0.3131 sec/batch
# Epoch: 3/20...  Training Step: 413...  Training loss: 1.9499...  0.3122 sec/batch
# Epoch: 3/20...  Training Step: 414...  Training loss: 1.9895...  0.3115 sec/batch
# Epoch: 3/20...  Training Step: 415...  Training loss: 1.9546...  0.3128 sec/batch
# Epoch: 3/20...  Training Step: 416...  Training loss: 1.9629...  0.3116 sec/batch
# Epoch: 3/20...  Training Step: 417...  Training loss: 1.9477...  0.3095 sec/batch
# Epoch: 3/20...  Training Step: 418...  Training loss: 1.9870...  0.3099 sec/batch
# Epoch: 3/20...  Training Step: 419...  Training loss: 1.9499...  0.3113 sec/batch
# Epoch: 3/20...  Training Step: 420...  Training loss: 1.9385...  0.3117 sec/batch
# Epoch: 3/20...  Training Step: 421...  Training loss: 1.9382...  0.3116 sec/batch
# Epoch: 3/20...  Training Step: 422...  Training loss: 1.9178...  0.3122 sec/batch
# Epoch: 3/20...  Training Step: 423...  Training loss: 1.9182...  0.3116 sec/batch
# Epoch: 3/20...  Training Step: 424...  Training loss: 1.9523...  0.3121 sec/batch
# Epoch: 3/20...  Training Step: 425...  Training loss: 1.9771...  0.3117 sec/batch
# Epoch: 3/20...  Training Step: 426...  Training loss: 1.9535...  0.3103 sec/batch
# Epoch: 3/20...  Training Step: 427...  Training loss: 1.9419...  0.3105 sec/batch
# Epoch: 3/20...  Training Step: 428...  Training loss: 1.9219...  0.3100 sec/batch
# Epoch: 3/20...  Training Step: 429...  Training loss: 1.9517...  0.3119 sec/batch
# Epoch: 3/20...  Training Step: 430...  Training loss: 1.9637...  0.3130 sec/batch
# Epoch: 3/20...  Training Step: 431...  Training loss: 1.9133...  0.3126 sec/batch
# Epoch: 3/20...  Training Step: 432...  Training loss: 1.9231...  0.3122 sec/batch
# Epoch: 3/20...  Training Step: 433...  Training loss: 1.9154...  0.3116 sec/batch
# Epoch: 3/20...  Training Step: 434...  Training loss: 1.8950...  0.3103 sec/batch
# Epoch: 3/20...  Training Step: 435...  Training loss: 1.8831...  0.3104 sec/batch
# Epoch: 3/20...  Training Step: 436...  Training loss: 1.9026...  0.3107 sec/batch
# Epoch: 3/20...  Training Step: 437...  Training loss: 1.8917...  0.3103 sec/batch
# Epoch: 3/20...  Training Step: 438...  Training loss: 1.9247...  0.3133 sec/batch
# Epoch: 3/20...  Training Step: 439...  Training loss: 1.8923...  0.3121 sec/batch
# Epoch: 3/20...  Training Step: 440...  Training loss: 1.8899...  0.3123 sec/batch
# Epoch: 3/20...  Training Step: 441...  Training loss: 1.9261...  0.3120 sec/batch
# Epoch: 3/20...  Training Step: 442...  Training loss: 1.8660...  0.3105 sec/batch
# Epoch: 3/20...  Training Step: 443...  Training loss: 1.9176...  0.3116 sec/batch
# Epoch: 3/20...  Training Step: 444...  Training loss: 1.8874...  0.3108 sec/batch
# Epoch: 3/20...  Training Step: 445...  Training loss: 1.8948...  0.3105 sec/batch
# Epoch: 3/20...  Training Step: 446...  Training loss: 1.9492...  0.3111 sec/batch
# Epoch: 3/20...  Training Step: 447...  Training loss: 1.8774...  0.3123 sec/batch
# Epoch: 3/20...  Training Step: 448...  Training loss: 1.9576...  0.3116 sec/batch
# Epoch: 3/20...  Training Step: 449...  Training loss: 1.9025...  0.3119 sec/batch
# Epoch: 3/20...  Training Step: 450...  Training loss: 1.8971...  0.3115 sec/batch
# Epoch: 3/20...  Training Step: 451...  Training loss: 1.8965...  0.3098 sec/batch
# Epoch: 3/20...  Training Step: 452...  Training loss: 1.9179...  0.3121 sec/batch
# Epoch: 3/20...  Training Step: 453...  Training loss: 1.9129...  0.3109 sec/batch
# Epoch: 3/20...  Training Step: 454...  Training loss: 1.8957...  0.3109 sec/batch
# Epoch: 3/20...  Training Step: 455...  Training loss: 1.8698...  0.3109 sec/batch
# Epoch: 3/20...  Training Step: 456...  Training loss: 1.9329...  0.3124 sec/batch
# Epoch: 3/20...  Training Step: 457...  Training loss: 1.8983...  0.3128 sec/batch
# Epoch: 3/20...  Training Step: 458...  Training loss: 1.9386...  0.3127 sec/batch
# Epoch: 3/20...  Training Step: 459...  Training loss: 1.9269...  0.3123 sec/batch
# Epoch: 3/20...  Training Step: 460...  Training loss: 1.9043...  0.3116 sec/batch
# Epoch: 3/20...  Training Step: 461...  Training loss: 1.8859...  0.3123 sec/batch
# Epoch: 3/20...  Training Step: 462...  Training loss: 1.9175...  0.3110 sec/batch
# Epoch: 3/20...  Training Step: 463...  Training loss: 1.9131...  0.3103 sec/batch
# Epoch: 3/20...  Training Step: 464...  Training loss: 1.8672...  0.3098 sec/batch
# Epoch: 3/20...  Training Step: 465...  Training loss: 1.8772...  0.3129 sec/batch
# Epoch: 3/20...  Training Step: 466...  Training loss: 1.8807...  0.3124 sec/batch
# Epoch: 3/20...  Training Step: 467...  Training loss: 1.9226...  0.3125 sec/batch
# Epoch: 3/20...  Training Step: 468...  Training loss: 1.9037...  0.3119 sec/batch
# Epoch: 3/20...  Training Step: 469...  Training loss: 1.9111...  0.3124 sec/batch
# Epoch: 3/20...  Training Step: 470...  Training loss: 1.8659...  0.3125 sec/batch
# Epoch: 3/20...  Training Step: 471...  Training loss: 1.8815...  0.3099 sec/batch
# Epoch: 3/20...  Training Step: 472...  Training loss: 1.9096...  0.3108 sec/batch
# Epoch: 3/20...  Training Step: 473...  Training loss: 1.8783...  0.3122 sec/batch
# Epoch: 3/20...  Training Step: 474...  Training loss: 1.8916...  0.3126 sec/batch
# Epoch: 3/20...  Training Step: 475...  Training loss: 1.8543...  0.3120 sec/batch
# Epoch: 3/20...  Training Step: 476...  Training loss: 1.8726...  0.3122 sec/batch
# Epoch: 3/20...  Training Step: 477...  Training loss: 1.8434...  0.3110 sec/batch
# Epoch: 3/20...  Training Step: 478...  Training loss: 1.8935...  0.3102 sec/batch
# Epoch: 3/20...  Training Step: 479...  Training loss: 1.8339...  0.3125 sec/batch
# Epoch: 3/20...  Training Step: 480...  Training loss: 1.8703...  0.3107 sec/batch
# Epoch: 3/20...  Training Step: 481...  Training loss: 1.8377...  0.3108 sec/batch
# Epoch: 3/20...  Training Step: 482...  Training loss: 1.8524...  0.3125 sec/batch
# Epoch: 3/20...  Training Step: 483...  Training loss: 1.8553...  0.3127 sec/batch
# Epoch: 3/20...  Training Step: 484...  Training loss: 1.8456...  0.3126 sec/batch
# Epoch: 3/20...  Training Step: 485...  Training loss: 1.8338...  0.3116 sec/batch
# Epoch: 3/20...  Training Step: 486...  Training loss: 1.8690...  0.3108 sec/batch
# Epoch: 3/20...  Training Step: 487...  Training loss: 1.8421...  0.3124 sec/batch
# Epoch: 3/20...  Training Step: 488...  Training loss: 1.8542...  0.3103 sec/batch
# Epoch: 3/20...  Training Step: 489...  Training loss: 1.8176...  0.3104 sec/batch
# Epoch: 3/20...  Training Step: 490...  Training loss: 1.8320...  0.3123 sec/batch
# Epoch: 3/20...  Training Step: 491...  Training loss: 1.8265...  0.3115 sec/batch
# Epoch: 3/20...  Training Step: 492...  Training loss: 1.8512...  0.3121 sec/batch
# Epoch: 3/20...  Training Step: 493...  Training loss: 1.8485...  0.3121 sec/batch
# Epoch: 3/20...  Training Step: 494...  Training loss: 1.8249...  0.3119 sec/batch
# Epoch: 3/20...  Training Step: 495...  Training loss: 1.8260...  0.3120 sec/batch
# Epoch: 3/20...  Training Step: 496...  Training loss: 1.8016...  0.3102 sec/batch
# Epoch: 3/20...  Training Step: 497...  Training loss: 1.8516...  0.3112 sec/batch
# Epoch: 3/20...  Training Step: 498...  Training loss: 1.8461...  0.3119 sec/batch
# Epoch: 3/20...  Training Step: 499...  Training loss: 1.8380...  0.3126 sec/batch
# Epoch: 3/20...  Training Step: 500...  Training loss: 1.8341...  0.3124 sec/batch
# Epoch: 3/20...  Training Step: 501...  Training loss: 1.8341...  0.3124 sec/batch
# Epoch: 3/20...  Training Step: 502...  Training loss: 1.8427...  0.3120 sec/batch
# Epoch: 3/20...  Training Step: 503...  Training loss: 1.8427...  0.3107 sec/batch
# Epoch: 3/20...  Training Step: 504...  Training loss: 1.8550...  0.3129 sec/batch
# Epoch: 3/20...  Training Step: 505...  Training loss: 1.8504...  0.3117 sec/batch
# Epoch: 3/20...  Training Step: 506...  Training loss: 1.8583...  0.3119 sec/batch
# Epoch: 3/20...  Training Step: 507...  Training loss: 1.8399...  0.3103 sec/batch
# Epoch: 3/20...  Training Step: 508...  Training loss: 1.8309...  0.3123 sec/batch
# Epoch: 3/20...  Training Step: 509...  Training loss: 1.8385...  0.3128 sec/batch
# Epoch: 3/20...  Training Step: 510...  Training loss: 1.8268...  0.3120 sec/batch
# Epoch: 3/20...  Training Step: 511...  Training loss: 1.8231...  0.3123 sec/batch
# Epoch: 3/20...  Training Step: 512...  Training loss: 1.7915...  0.3129 sec/batch
# Epoch: 3/20...  Training Step: 513...  Training loss: 1.8491...  0.3126 sec/batch
# Epoch: 3/20...  Training Step: 514...  Training loss: 1.8227...  0.3123 sec/batch
# Epoch: 3/20...  Training Step: 515...  Training loss: 1.8366...  0.3105 sec/batch
# Epoch: 3/20...  Training Step: 516...  Training loss: 1.8347...  0.3127 sec/batch
# Epoch: 3/20...  Training Step: 517...  Training loss: 1.8406...  0.3127 sec/batch
# Epoch: 3/20...  Training Step: 518...  Training loss: 1.8007...  0.3128 sec/batch
# Epoch: 3/20...  Training Step: 519...  Training loss: 1.8029...  0.3124 sec/batch
# Epoch: 3/20...  Training Step: 520...  Training loss: 1.8572...  0.3129 sec/batch
# Epoch: 3/20...  Training Step: 521...  Training loss: 1.8185...  0.3122 sec/batch
# Epoch: 3/20...  Training Step: 522...  Training loss: 1.7736...  0.3124 sec/batch
# Epoch: 3/20...  Training Step: 523...  Training loss: 1.8392...  0.3107 sec/batch
# Epoch: 3/20...  Training Step: 524...  Training loss: 1.8419...  0.3119 sec/batch
# Epoch: 3/20...  Training Step: 525...  Training loss: 1.8195...  0.3118 sec/batch
# Epoch: 3/20...  Training Step: 526...  Training loss: 1.8127...  0.3124 sec/batch
# Epoch: 3/20...  Training Step: 527...  Training loss: 1.7900...  0.3127 sec/batch
# Epoch: 3/20...  Training Step: 528...  Training loss: 1.7921...  0.3124 sec/batch
# Epoch: 3/20...  Training Step: 529...  Training loss: 1.8335...  0.3116 sec/batch
# Epoch: 3/20...  Training Step: 530...  Training loss: 1.8274...  0.3119 sec/batch
# Epoch: 3/20...  Training Step: 531...  Training loss: 1.8173...  0.3120 sec/batch
# Epoch: 3/20...  Training Step: 532...  Training loss: 1.8187...  0.3120 sec/batch
# Epoch: 3/20...  Training Step: 533...  Training loss: 1.8325...  0.3126 sec/batch
# Epoch: 3/20...  Training Step: 534...  Training loss: 1.8215...  0.3122 sec/batch
# Epoch: 3/20...  Training Step: 535...  Training loss: 1.8440...  0.3123 sec/batch
# Epoch: 3/20...  Training Step: 536...  Training loss: 1.8113...  0.3120 sec/batch
# Epoch: 3/20...  Training Step: 537...  Training loss: 1.8516...  0.3121 sec/batch
# Epoch: 3/20...  Training Step: 538...  Training loss: 1.8093...  0.3119 sec/batch
# Epoch: 3/20...  Training Step: 539...  Training loss: 1.8141...  0.3104 sec/batch
# Epoch: 3/20...  Training Step: 540...  Training loss: 1.8210...  0.3103 sec/batch
# Epoch: 3/20...  Training Step: 541...  Training loss: 1.7886...  0.3119 sec/batch
# Epoch: 3/20...  Training Step: 542...  Training loss: 1.8244...  0.3130 sec/batch
# Epoch: 3/20...  Training Step: 543...  Training loss: 1.8128...  0.3128 sec/batch
# Epoch: 3/20...  Training Step: 544...  Training loss: 1.8387...  0.3121 sec/batch
# Epoch: 3/20...  Training Step: 545...  Training loss: 1.8160...  0.3117 sec/batch
# Epoch: 3/20...  Training Step: 546...  Training loss: 1.8001...  0.3116 sec/batch
# Epoch: 3/20...  Training Step: 547...  Training loss: 1.7992...  0.3104 sec/batch
# Epoch: 3/20...  Training Step: 548...  Training loss: 1.8279...  0.3127 sec/batch
# Epoch: 3/20...  Training Step: 549...  Training loss: 1.8087...  0.3123 sec/batch
# Epoch: 3/20...  Training Step: 550...  Training loss: 1.8241...  0.3121 sec/batch
# Epoch: 3/20...  Training Step: 551...  Training loss: 1.7931...  0.3127 sec/batch
# Epoch: 3/20...  Training Step: 552...  Training loss: 1.7934...  0.3123 sec/batch
# Epoch: 3/20...  Training Step: 553...  Training loss: 1.8184...  0.3121 sec/batch
# Epoch: 3/20...  Training Step: 554...  Training loss: 1.7918...  0.3121 sec/batch
# Epoch: 3/20...  Training Step: 555...  Training loss: 1.7708...  0.3126 sec/batch
# Epoch: 3/20...  Training Step: 556...  Training loss: 1.8213...  0.3112 sec/batch
# Epoch: 3/20...  Training Step: 557...  Training loss: 1.8376...  0.3114 sec/batch
# Epoch: 3/20...  Training Step: 558...  Training loss: 1.7923...  0.3128 sec/batch
# Epoch: 3/20...  Training Step: 559...  Training loss: 1.8133...  0.3125 sec/batch
# Epoch: 3/20...  Training Step: 560...  Training loss: 1.8002...  0.3131 sec/batch
# Epoch: 3/20...  Training Step: 561...  Training loss: 1.7974...  0.3124 sec/batch
# Epoch: 3/20...  Training Step: 562...  Training loss: 1.7933...  0.3121 sec/batch
# Epoch: 3/20...  Training Step: 563...  Training loss: 1.8100...  0.3128 sec/batch
# Epoch: 3/20...  Training Step: 564...  Training loss: 1.8467...  0.3122 sec/batch
# Epoch: 3/20...  Training Step: 565...  Training loss: 1.7812...  0.3125 sec/batch
# Epoch: 3/20...  Training Step: 566...  Training loss: 1.7910...  0.3130 sec/batch
# Epoch: 3/20...  Training Step: 567...  Training loss: 1.7715...  0.3128 sec/batch
# Epoch: 3/20...  Training Step: 568...  Training loss: 1.7848...  0.3125 sec/batch
# Epoch: 3/20...  Training Step: 569...  Training loss: 1.8196...  0.3121 sec/batch
# Epoch: 3/20...  Training Step: 570...  Training loss: 1.8024...  0.3128 sec/batch
# Epoch: 3/20...  Training Step: 571...  Training loss: 1.7978...  0.3124 sec/batch
# Epoch: 3/20...  Training Step: 572...  Training loss: 1.7809...  0.3124 sec/batch
# Epoch: 3/20...  Training Step: 573...  Training loss: 1.7690...  0.3121 sec/batch
# Epoch: 3/20...  Training Step: 574...  Training loss: 1.7988...  0.3120 sec/batch
# Epoch: 3/20...  Training Step: 575...  Training loss: 1.7648...  0.3124 sec/batch
# Epoch: 3/20...  Training Step: 576...  Training loss: 1.7531...  0.3125 sec/batch
# Epoch: 3/20...  Training Step: 577...  Training loss: 1.7569...  0.3128 sec/batch
# Epoch: 3/20...  Training Step: 578...  Training loss: 1.7751...  0.3113 sec/batch
# Epoch: 3/20...  Training Step: 579...  Training loss: 1.7761...  0.3106 sec/batch
# Epoch: 3/20...  Training Step: 580...  Training loss: 1.7979...  0.3108 sec/batch
# Epoch: 3/20...  Training Step: 581...  Training loss: 1.7744...  0.3130 sec/batch
# Epoch: 3/20...  Training Step: 582...  Training loss: 1.7671...  0.3119 sec/batch
# Epoch: 3/20...  Training Step: 583...  Training loss: 1.7898...  0.3127 sec/batch
# Epoch: 3/20...  Training Step: 584...  Training loss: 1.7687...  0.3127 sec/batch
# Epoch: 3/20...  Training Step: 585...  Training loss: 1.7642...  0.3126 sec/batch
# Epoch: 3/20...  Training Step: 586...  Training loss: 1.7820...  0.3127 sec/batch
# ...
# Epoch: 20/20...  Training Step: 3771...  Training loss: 1.2266...  0.3128 sec/batch
# Epoch: 20/20...  Training Step: 3772...  Training loss: 1.2139...  0.3120 sec/batch
# Epoch: 20/20...  Training Step: 3773...  Training loss: 1.2031...  0.3123 sec/batch
# Epoch: 20/20...  Training Step: 3774...  Training loss: 1.2158...  0.3121 sec/batch
# Epoch: 20/20...  Training Step: 3775...  Training loss: 1.2265...  0.3123 sec/batch
# Epoch: 20/20...  Training Step: 3776...  Training loss: 1.2286...  0.3129 sec/batch
# Epoch: 20/20...  Training Step: 3777...  Training loss: 1.2126...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3778...  Training loss: 1.1990...  0.3125 sec/batch
# Epoch: 20/20...  Training Step: 3779...  Training loss: 1.2299...  0.3123 sec/batch
# Epoch: 20/20...  Training Step: 3780...  Training loss: 1.2476...  0.3133 sec/batch
# Epoch: 20/20...  Training Step: 3781...  Training loss: 1.2197...  0.3127 sec/batch
# Epoch: 20/20...  Training Step: 3782...  Training loss: 1.2498...  0.3128 sec/batch
# Epoch: 20/20...  Training Step: 3783...  Training loss: 1.2151...  0.3131 sec/batch
# Epoch: 20/20...  Training Step: 3784...  Training loss: 1.2305...  0.3124 sec/batch
# Epoch: 20/20...  Training Step: 3785...  Training loss: 1.2138...  0.3123 sec/batch
# Epoch: 20/20...  Training Step: 3786...  Training loss: 1.2387...  0.3124 sec/batch
# Epoch: 20/20...  Training Step: 3787...  Training loss: 1.2247...  0.3125 sec/batch
# Epoch: 20/20...  Training Step: 3788...  Training loss: 1.1709...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3789...  Training loss: 1.1925...  0.3124 sec/batch
# Epoch: 20/20...  Training Step: 3790...  Training loss: 1.2346...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3791...  Training loss: 1.2327...  0.3123 sec/batch
# Epoch: 20/20...  Training Step: 3792...  Training loss: 1.2420...  0.3159 sec/batch
# Epoch: 20/20...  Training Step: 3793...  Training loss: 1.2036...  0.3146 sec/batch
# Epoch: 20/20...  Training Step: 3794...  Training loss: 1.1976...  0.3125 sec/batch
# Epoch: 20/20...  Training Step: 3795...  Training loss: 1.2200...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3796...  Training loss: 1.2292...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3797...  Training loss: 1.2034...  0.3125 sec/batch
# Epoch: 20/20...  Training Step: 3798...  Training loss: 1.2225...  0.3129 sec/batch
# Epoch: 20/20...  Training Step: 3799...  Training loss: 1.1933...  0.3150 sec/batch
# Epoch: 20/20...  Training Step: 3800...  Training loss: 1.1762...  0.3144 sec/batch
# Epoch: 20/20...  Training Step: 3801...  Training loss: 1.1770...  0.3103 sec/batch
# Epoch: 20/20...  Training Step: 3802...  Training loss: 1.2057...  0.3121 sec/batch
# Epoch: 20/20...  Training Step: 3803...  Training loss: 1.1923...  0.3133 sec/batch
# Epoch: 20/20...  Training Step: 3804...  Training loss: 1.2550...  0.3122 sec/batch
# Epoch: 20/20...  Training Step: 3805...  Training loss: 1.2100...  0.3136 sec/batch
# Epoch: 20/20...  Training Step: 3806...  Training loss: 1.1934...  0.3121 sec/batch
# Epoch: 20/20...  Training Step: 3807...  Training loss: 1.2191...  0.3158 sec/batch
# Epoch: 20/20...  Training Step: 3808...  Training loss: 1.1900...  0.3125 sec/batch
# Epoch: 20/20...  Training Step: 3809...  Training loss: 1.1994...  0.3124 sec/batch
# Epoch: 20/20...  Training Step: 3810...  Training loss: 1.2099...  0.3123 sec/batch
# Epoch: 20/20...  Training Step: 3811...  Training loss: 1.2050...  0.3124 sec/batch
# Epoch: 20/20...  Training Step: 3812...  Training loss: 1.2238...  0.3125 sec/batch
# Epoch: 20/20...  Training Step: 3813...  Training loss: 1.1821...  0.3141 sec/batch
# Epoch: 20/20...  Training Step: 3814...  Training loss: 1.2495...  0.3124 sec/batch
# Epoch: 20/20...  Training Step: 3815...  Training loss: 1.2159...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3816...  Training loss: 1.2188...  0.3153 sec/batch
# Epoch: 20/20...  Training Step: 3817...  Training loss: 1.2025...  0.3124 sec/batch
# Epoch: 20/20...  Training Step: 3818...  Training loss: 1.2164...  0.3118 sec/batch
# Epoch: 20/20...  Training Step: 3819...  Training loss: 1.2196...  0.3122 sec/batch
# Epoch: 20/20...  Training Step: 3820...  Training loss: 1.1986...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3821...  Training loss: 1.1958...  0.3127 sec/batch
# Epoch: 20/20...  Training Step: 3822...  Training loss: 1.2474...  0.3130 sec/batch
# Epoch: 20/20...  Training Step: 3823...  Training loss: 1.2141...  0.3161 sec/batch
# Epoch: 20/20...  Training Step: 3824...  Training loss: 1.2603...  0.3125 sec/batch
# Epoch: 20/20...  Training Step: 3825...  Training loss: 1.2399...  0.3124 sec/batch
# Epoch: 20/20...  Training Step: 3826...  Training loss: 1.2248...  0.3127 sec/batch
# Epoch: 20/20...  Training Step: 3827...  Training loss: 1.2172...  0.3123 sec/batch
# Epoch: 20/20...  Training Step: 3828...  Training loss: 1.2179...  0.3124 sec/batch
# Epoch: 20/20...  Training Step: 3829...  Training loss: 1.2326...  0.3130 sec/batch
# Epoch: 20/20...  Training Step: 3830...  Training loss: 1.2065...  0.3127 sec/batch
# Epoch: 20/20...  Training Step: 3831...  Training loss: 1.2192...  0.3129 sec/batch
# Epoch: 20/20...  Training Step: 3832...  Training loss: 1.2067...  0.3129 sec/batch
# Epoch: 20/20...  Training Step: 3833...  Training loss: 1.2578...  0.3128 sec/batch
# Epoch: 20/20...  Training Step: 3834...  Training loss: 1.2394...  0.3123 sec/batch
# Epoch: 20/20...  Training Step: 3835...  Training loss: 1.2477...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3836...  Training loss: 1.1945...  0.3120 sec/batch
# Epoch: 20/20...  Training Step: 3837...  Training loss: 1.2255...  0.3124 sec/batch
# Epoch: 20/20...  Training Step: 3838...  Training loss: 1.2306...  0.3127 sec/batch
# Epoch: 20/20...  Training Step: 3839...  Training loss: 1.2099...  0.3125 sec/batch
# Epoch: 20/20...  Training Step: 3840...  Training loss: 1.1982...  0.3124 sec/batch
# Epoch: 20/20...  Training Step: 3841...  Training loss: 1.1632...  0.3129 sec/batch
# Epoch: 20/20...  Training Step: 3842...  Training loss: 1.2107...  0.3130 sec/batch
# Epoch: 20/20...  Training Step: 3843...  Training loss: 1.1822...  0.3131 sec/batch
# Epoch: 20/20...  Training Step: 3844...  Training loss: 1.2063...  0.3124 sec/batch
# Epoch: 20/20...  Training Step: 3845...  Training loss: 1.1817...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3846...  Training loss: 1.2160...  0.3130 sec/batch
# Epoch: 20/20...  Training Step: 3847...  Training loss: 1.1870...  0.3130 sec/batch
# Epoch: 20/20...  Training Step: 3848...  Training loss: 1.2133...  0.3123 sec/batch
# Epoch: 20/20...  Training Step: 3849...  Training loss: 1.1940...  0.3134 sec/batch
# Epoch: 20/20...  Training Step: 3850...  Training loss: 1.1938...  0.3123 sec/batch
# Epoch: 20/20...  Training Step: 3851...  Training loss: 1.1837...  0.3121 sec/batch
# Epoch: 20/20...  Training Step: 3852...  Training loss: 1.2161...  0.3121 sec/batch
# Epoch: 20/20...  Training Step: 3853...  Training loss: 1.1918...  0.3124 sec/batch
# Epoch: 20/20...  Training Step: 3854...  Training loss: 1.2052...  0.3127 sec/batch
# Epoch: 20/20...  Training Step: 3855...  Training loss: 1.1901...  0.3152 sec/batch
# Epoch: 20/20...  Training Step: 3856...  Training loss: 1.1775...  0.3151 sec/batch
# Epoch: 20/20...  Training Step: 3857...  Training loss: 1.2007...  0.3125 sec/batch
# Epoch: 20/20...  Training Step: 3858...  Training loss: 1.2216...  0.3123 sec/batch
# Epoch: 20/20...  Training Step: 3859...  Training loss: 1.2107...  0.3123 sec/batch
# Epoch: 20/20...  Training Step: 3860...  Training loss: 1.1821...  0.3121 sec/batch
# Epoch: 20/20...  Training Step: 3861...  Training loss: 1.1968...  0.3133 sec/batch
# Epoch: 20/20...  Training Step: 3862...  Training loss: 1.1927...  0.3127 sec/batch
# Epoch: 20/20...  Training Step: 3863...  Training loss: 1.2148...  0.3155 sec/batch
# Epoch: 20/20...  Training Step: 3864...  Training loss: 1.2045...  0.3127 sec/batch
# Epoch: 20/20...  Training Step: 3865...  Training loss: 1.2138...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3866...  Training loss: 1.1991...  0.3121 sec/batch
# Epoch: 20/20...  Training Step: 3867...  Training loss: 1.1953...  0.3124 sec/batch
# Epoch: 20/20...  Training Step: 3868...  Training loss: 1.2016...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3869...  Training loss: 1.2077...  0.3121 sec/batch
# Epoch: 20/20...  Training Step: 3870...  Training loss: 1.2180...  0.3127 sec/batch
# Epoch: 20/20...  Training Step: 3871...  Training loss: 1.1912...  0.3167 sec/batch
# Epoch: 20/20...  Training Step: 3872...  Training loss: 1.2298...  0.3129 sec/batch
# Epoch: 20/20...  Training Step: 3873...  Training loss: 1.1871...  0.3124 sec/batch
# Epoch: 20/20...  Training Step: 3874...  Training loss: 1.2066...  0.3122 sec/batch
# Epoch: 20/20...  Training Step: 3875...  Training loss: 1.2272...  0.3119 sec/batch
# Epoch: 20/20...  Training Step: 3876...  Training loss: 1.1976...  0.3119 sec/batch
# Epoch: 20/20...  Training Step: 3877...  Training loss: 1.1848...  0.3121 sec/batch
# Epoch: 20/20...  Training Step: 3878...  Training loss: 1.1804...  0.3121 sec/batch
# Epoch: 20/20...  Training Step: 3879...  Training loss: 1.2217...  0.3145 sec/batch
# Epoch: 20/20...  Training Step: 3880...  Training loss: 1.2184...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3881...  Training loss: 1.2095...  0.3125 sec/batch
# Epoch: 20/20...  Training Step: 3882...  Training loss: 1.2103...  0.3120 sec/batch
# Epoch: 20/20...  Training Step: 3883...  Training loss: 1.2107...  0.3131 sec/batch
# Epoch: 20/20...  Training Step: 3884...  Training loss: 1.1767...  0.3121 sec/batch
# Epoch: 20/20...  Training Step: 3885...  Training loss: 1.1656...  0.3123 sec/batch
# Epoch: 20/20...  Training Step: 3886...  Training loss: 1.2075...  0.3166 sec/batch
# Epoch: 20/20...  Training Step: 3887...  Training loss: 1.1947...  0.3123 sec/batch
# Epoch: 20/20...  Training Step: 3888...  Training loss: 1.1697...  0.3120 sec/batch
# Epoch: 20/20...  Training Step: 3889...  Training loss: 1.2185...  0.3132 sec/batch
# Epoch: 20/20...  Training Step: 3890...  Training loss: 1.2191...  0.3125 sec/batch
# Epoch: 20/20...  Training Step: 3891...  Training loss: 1.1984...  0.3131 sec/batch
# Epoch: 20/20...  Training Step: 3892...  Training loss: 1.1677...  0.3118 sec/batch
# Epoch: 20/20...  Training Step: 3893...  Training loss: 1.1596...  0.3125 sec/batch
# Epoch: 20/20...  Training Step: 3894...  Training loss: 1.1893...  0.3122 sec/batch
# Epoch: 20/20...  Training Step: 3895...  Training loss: 1.2276...  0.3123 sec/batch
# Epoch: 20/20...  Training Step: 3896...  Training loss: 1.2148...  0.3130 sec/batch
# Epoch: 20/20...  Training Step: 3897...  Training loss: 1.2201...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3898...  Training loss: 1.2174...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3899...  Training loss: 1.2336...  0.3131 sec/batch
# Epoch: 20/20...  Training Step: 3900...  Training loss: 1.2294...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3901...  Training loss: 1.2107...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3902...  Training loss: 1.2172...  0.3158 sec/batch
# Epoch: 20/20...  Training Step: 3903...  Training loss: 1.2539...  0.3134 sec/batch
# Epoch: 20/20...  Training Step: 3904...  Training loss: 1.2254...  0.3125 sec/batch
# Epoch: 20/20...  Training Step: 3905...  Training loss: 1.1996...  0.3131 sec/batch
# Epoch: 20/20...  Training Step: 3906...  Training loss: 1.2337...  0.3123 sec/batch
# Epoch: 20/20...  Training Step: 3907...  Training loss: 1.2024...  0.3123 sec/batch
# Epoch: 20/20...  Training Step: 3908...  Training loss: 1.2394...  0.3122 sec/batch
# Epoch: 20/20...  Training Step: 3909...  Training loss: 1.2131...  0.3123 sec/batch
# Epoch: 20/20...  Training Step: 3910...  Training loss: 1.2360...  0.3157 sec/batch
# Epoch: 20/20...  Training Step: 3911...  Training loss: 1.2268...  0.3154 sec/batch
# Epoch: 20/20...  Training Step: 3912...  Training loss: 1.2077...  0.3125 sec/batch
# Epoch: 20/20...  Training Step: 3913...  Training loss: 1.1800...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3914...  Training loss: 1.1818...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3915...  Training loss: 1.2253...  0.3125 sec/batch
# Epoch: 20/20...  Training Step: 3916...  Training loss: 1.2103...  0.3156 sec/batch
# Epoch: 20/20...  Training Step: 3917...  Training loss: 1.2021...  0.3167 sec/batch
# Epoch: 20/20...  Training Step: 3918...  Training loss: 1.2070...  0.3124 sec/batch
# Epoch: 20/20...  Training Step: 3919...  Training loss: 1.2098...  0.3128 sec/batch
# Epoch: 20/20...  Training Step: 3920...  Training loss: 1.1974...  0.3127 sec/batch
# Epoch: 20/20...  Training Step: 3921...  Training loss: 1.1784...  0.3120 sec/batch
# Epoch: 20/20...  Training Step: 3922...  Training loss: 1.2215...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3923...  Training loss: 1.2242...  0.3122 sec/batch
# Epoch: 20/20...  Training Step: 3924...  Training loss: 1.2186...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3925...  Training loss: 1.1924...  0.3129 sec/batch
# Epoch: 20/20...  Training Step: 3926...  Training loss: 1.2164...  0.3166 sec/batch
# Epoch: 20/20...  Training Step: 3927...  Training loss: 1.2109...  0.3149 sec/batch
# Epoch: 20/20...  Training Step: 3928...  Training loss: 1.2004...  0.3121 sec/batch
# Epoch: 20/20...  Training Step: 3929...  Training loss: 1.2232...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3930...  Training loss: 1.2727...  0.3127 sec/batch
# Epoch: 20/20...  Training Step: 3931...  Training loss: 1.2289...  0.3132 sec/batch
# Epoch: 20/20...  Training Step: 3932...  Training loss: 1.2163...  0.3129 sec/batch
# Epoch: 20/20...  Training Step: 3933...  Training loss: 1.1988...  0.3168 sec/batch
# Epoch: 20/20...  Training Step: 3934...  Training loss: 1.1926...  0.3127 sec/batch
# Epoch: 20/20...  Training Step: 3935...  Training loss: 1.2399...  0.3123 sec/batch
# Epoch: 20/20...  Training Step: 3936...  Training loss: 1.2154...  0.3119 sec/batch
# Epoch: 20/20...  Training Step: 3937...  Training loss: 1.2162...  0.3124 sec/batch
# Epoch: 20/20...  Training Step: 3938...  Training loss: 1.1766...  0.3127 sec/batch
# Epoch: 20/20...  Training Step: 3939...  Training loss: 1.2064...  0.3128 sec/batch
# Epoch: 20/20...  Training Step: 3940...  Training loss: 1.2439...  0.3125 sec/batch
# Epoch: 20/20...  Training Step: 3941...  Training loss: 1.1774...  0.3154 sec/batch
# Epoch: 20/20...  Training Step: 3942...  Training loss: 1.1893...  0.3149 sec/batch
# Epoch: 20/20...  Training Step: 3943...  Training loss: 1.1962...  0.3115 sec/batch
# Epoch: 20/20...  Training Step: 3944...  Training loss: 1.2084...  0.3132 sec/batch
# Epoch: 20/20...  Training Step: 3945...  Training loss: 1.2043...  0.3128 sec/batch
# Epoch: 20/20...  Training Step: 3946...  Training loss: 1.1883...  0.3127 sec/batch
# Epoch: 20/20...  Training Step: 3947...  Training loss: 1.1948...  0.3131 sec/batch
# Epoch: 20/20...  Training Step: 3948...  Training loss: 1.1909...  0.3123 sec/batch
# Epoch: 20/20...  Training Step: 3949...  Training loss: 1.2328...  0.3126 sec/batch
# Epoch: 20/20...  Training Step: 3950...  Training loss: 1.1927...  0.3128 sec/batch
# Epoch: 20/20...  Training Step: 3951...  Training loss: 1.2024...  0.3133 sec/batch
# Epoch: 20/20...  Training Step: 3952...  Training loss: 1.2120...  0.3128 sec/batch
# Epoch: 20/20...  Training Step: 3953...  Training loss: 1.1767...  0.3121 sec/batch
# Epoch: 20/20...  Training Step: 3954...  Training loss: 1.2003...  0.3120 sec/batch
# Epoch: 20/20...  Training Step: 3955...  Training loss: 1.2133...  0.3133 sec/batch
# Epoch: 20/20...  Training Step: 3956...  Training loss: 1.1979...  0.3127 sec/batch
# Epoch: 20/20...  Training Step: 3957...  Training loss: 1.1708...  0.3160 sec/batch
# Epoch: 20/20...  Training Step: 3958...  Training loss: 1.2109...  0.3122 sec/batch
# Epoch: 20/20...  Training Step: 3959...  Training loss: 1.2011...  0.3123 sec/batch
# Epoch: 20/20...  Training Step: 3960...  Training loss: 1.2025...  0.3120 sec/batch

# %% [markdown]
# #### Saved checkpoints
#
# Read up on saving and loading checkpoints here: https://www.tensorflow.org/programmers_guide/variables

# %%
tf.train.get_checkpoint_state('checkpoints')
# Out:
# model_checkpoint_path: "checkpoints/i3960_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3960_l512.ckpt"

# %% [markdown]
# ## Sampling
#
# Now that the network is trained, we'll can use it to generate new text. The idea is that we pass in a character, then the network will predict the next character. We can use the new one, to predict the next one. And we keep doing this to generate all new text. I also included some functionality to prime the network with some text by passing in a string and building up a state from that.
#
# The network gives us predictions for each character. To reduce noise and make things a little less random, I'm going to only choose a new character from the top N most likely characters.

# %%
def pick_top_n(preds, vocab_size, top_n=5):
    p = np.squeeze(preds)
    p[np.argsort(p)[:-top_n]] = 0
    p = p / np.sum(p)
    c = np.random.choice(vocab_size, 1, p=p)[0]
    return c

# %%
def sample(checkpoint, n_samples, lstm_size, vocab_size, prime="The "):
    samples = [c for c in prime]
    model = CharRNN(len(vocab), lstm_size=lstm_size, sampling=True)
    saver = tf.train.Saver()
    with tf.Session() as sess:
        saver.restore(sess, checkpoint)
        new_state = sess.run(model.initial_state)
        for c in prime:
            x = np.zeros((1, 1))
            x[0,0] = vocab_to_int[c]
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

        c = pick_top_n(preds, len(vocab))
        samples.append(int_to_vocab[c])

        for i in range(n_samples):
            x[0,0] = c
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

            c = pick_top_n(preds, len(vocab))
            samples.append(int_to_vocab[c])
        
    return ''.join(samples)

# %% [markdown]
# Here, pass in the path to a checkpoint and sample from the network.

# %%
tf.train.latest_checkpoint('checkpoints')
# Out:
# 'checkpoints/i3960_l512.ckpt'

# %%
checkpoint = tf.train.latest_checkpoint('checkpoints')
samp = sample(checkpoint, 2000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/i3960_l512.ckpt
# Farther.
#
# "I don't know what is no one to think?"
#
# "What am I hade a conversation, they, that I want, I've been imperielly."
#
# And alrass of all that he was not answered by now there, and the
# cold at the concultional present the point of thinking that had been
# at harm from his chairs when he would have left home to be saying. The sack
# of the priest asked a strange tone that was all they still happineds,
# and to be a sister-in-liw, and he said:
#
# "Anna shall be that?.. In's always deciding."
#
# The point of his face was a stay, and who cranged, as it were. He
# saw she was at him, but there was they send to the sere exchenment
# would be at take in a complete carriage. He saw that that they went into
# her expected and helper, and was all the strength of her father.
#
# This came of always it. He had tried to believe it. She had not
# been bowing. He could him alone his brother, to how it was shooting whether
# he was such a sincere, that she won't be sure of her to send the country.
#
# "When he has been distinctly in the most immense subject of the men. And
# they won't talk, I wanted think on a bring in propost than, that you can
# be angry," she said, went on.
#
# "All anyone have a sense of secretary, but I shall be done in this
# water."
#
# The carriage was as they had angry, and she was always to get themselves.
# The doctor, his fingers, whether the deach was all seemed. He saw it
# to seem him, and shrill at all so in her expression, but he were at
# a moment in that could have been suck and contemptuously on some
# sort of his own whole best in a land of a sort of success, and an
# impression of a baby the carriage, and with himself this he was to be delighted with
# something in his crost. This was the familiar soute of shorts offer at
# that sound.
#
# The condrov only which was a stranger at the same sound of his feeling,
# and they were sure in the same tentement to this world, he could how and
# too true. She went on; there was nothing, to see had been seen in
# him, and had blew the conviction of the farm, ta

# %%
checkpoint = 'checkpoints/i200_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/i200_l512.ckpt
# Farsed.,"" shand ather, the the
# sile sasinet the sande tor ale has the
# thing ous ot at on whes and wotha hom the presing he sans tor hite
# hars the were hid an the the tore sat ha wers sor whe were hiss too hes than ar sore har and ans ale whe herdesing the son to meshe afs and orting the touth he hom ther tarting ther as andist her ald her the the hers old ha toreres tarin on hat he torith to her her to what the sor and he sor and to this se thit his
# sonde hith ander ond thit tho terade th soud ton thish he were he her and
# whith and time alt an thas his
# the tone sore his an was the all his whing ha thes warel hus
# wers thin thim tiling, ald tor hith whers
# hot he sorthers ond has wer the sole sit her onsat ha castor of the
# her anding toring him hime
# sile sit he wald he the passerit the
# her ton to met out ther sounthers
# of the so teo tile som he his
# thersengong, that and asd in thor the
# che thing tho here souss he as te here sous aldile to she sast of and tore sor hes an ale se son her soress

# %%
checkpoint = 'checkpoints/i600_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/i600_l512.ckpt
# Farn hount of the
# plonse,. "I've not and the same the ment to son of a sain, and his sund that in the muse on the cold in the meastent, and
# she don't all me and her the monter to said that he were to be
# sourd his hussered of thingess out of the carerange on she had had say at her anyther wook in a poiling at how him. He could he was the compite on his fros herself, and sound that so the mante with his suppity, at the sending of her alloned. And a wains a donick of
# her, he had been
# the
# consestor and that her this hus heresed, wanding on a cheating. The seach he was nothing his feated to hand
# and and and his sinters and he could be not his so what he said a some his wands, sut in to buttered and thought his fich astered to the shall. The prince were of homesters, as she said to bark as stropped. "In had
# batky thinking. His arries of stirk thourse and what sond to me, the peestion was to she sooked
# his. I sentt one suchenses of the mears, whine while how, then inta did net here alout offrenth

# %%
checkpoint = 'checkpoints/i1200_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
